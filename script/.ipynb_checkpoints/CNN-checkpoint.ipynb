# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.transforms as T
import torchvision
import matplotlib.pyplot as plt
import numpy as np
import os,sys
from PIL import Image
from pathlib import Path
from tqdm import tqdm

from helper_functions import *

# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
NBR_EPOCHS = 2
BATCH_SIZE = 10
LEARNING_RATE = 1e-3

# %%
from torch.utils.data import Dataset, DataLoader
class imagesDataset(Dataset): 
    
    def __init__(self):
        imgs_init, gt_imgs_init = load_train_dataset()
        
        # Data augmentation
        self.imgs = compose_all_functions_for_data(imgs_init)
        self.gt_imgs = compose_all_functions_for_data(gt_imgs_init)
        self.n_samples = len(self.imgs)
        
    def __getitem__(self, index):
        return self.imgs[index], self.gt_imgs[index]

    def __len__(self):
        return self.n_samples


# create dataset
torch.manual_seed(1)
dataset = imagesDataset()
train_loader = torch.utils.data.DataLoader(dataset, batch_size = BATCH_SIZE, shuffle = True)

# %%
img_temp = dataset[5432][0]
to_PIL = T.ToPILImage()
to_PIL(img_temp)
# Out:
# <PIL.Image.Image image mode=RGB size=400x400 at 0x7FE3E7F1DFA0>

# %%
class ConvNet(nn.Module):
    def __init__(self):
        super(ConvNet, self).__init__()
        
        # 
        self.pool_d = nn.MaxPool2d(2, 2)
        self.pool_u = nn.Upsample(scale_factor=2)
        
        # Activation function
        self.activ = nn.ReLU()
        
        # Convolution Downwards
        self.conv_1 = nn.Conv2d(3, 64, (3,3), padding=(2, 2))
        self.conv_2 = nn.Conv2d(64, 64, (3,3), padding=(2, 2))
        
        self.conv_3 = nn.Conv2d(64, 128, (3,3), padding=(2, 2))
        self.conv_4 = nn.Conv2d(128, 128, (3,3), padding=(2, 2))
        
        self.conv_5 = nn.Conv2d(128, 256, (3,3), padding=(2, 2))
        self.conv_6 = nn.Conv2d(256, 256, (3,3), padding=(2, 2))
        
        self.conv_7 = nn.Conv2d(256, 512, (3,3), padding=(2, 2))
        self.conv_8 = nn.Conv2d(512, 512, (3,3), padding=(2, 2))
        
        self.conv_9 = nn.Conv2d(512, 1024, (3,3), padding=(2, 2))
        self.conv_10 = nn.Conv2d(1024, 1024, (3,3), padding=(2, 2))
        
        
        # Upconvolution
        self.upconv_1 = nn.Conv2d(512+1024, 512, (3,3), padding=(2, 2))
        self.upconv_2 = nn.Conv2d(512, 512, (3,3), padding=(2, 2))
        
        self.upconv_3 = nn.Conv2d(256+512, 256, (3,3), padding=(2, 2))
        self.upconv_4 = nn.Conv2d(256, 256, (3,3), padding=(2, 2))
        
        self.upconv_5 = nn.Conv2d(128+256, 128, (3,3), padding=(2, 2))
        self.upconv_6 = nn.Conv2d(128, 128, (3,3), padding=(2, 2))
        
        self.upconv_7 = nn.Conv2d(64+128, 64, (3,3), padding=(2, 2))
        self.upconv_8 = nn.Conv2d(64, 64, (3,3), padding=(2, 2))
        self.upconv_9 = nn.Conv2d(64, 2, (1,1), padding=(2, 2))


    def forward(self, x):
        # Convolution with activation and max_pooling
        xd_1 = self.pool_d(self.activ(self.conv_1(x)))
        xd_2 = self.activ(self.conv_2(xd_1))
        
        xd_3 = self.pool_d(self.activ(self.conv_3(xd_2)))
        xd_4 = self.activ(self.conv_4(xd_3))
        
        xd_5 = self.pool_d(self.activ(self.conv_5(xd_4)))
        xd_6 = self.activ(self.conv_6(xd_5))
        
        xd_7 = self.pool_d(self.activ(self.conv_7(xd_6)))
        xd_8 = self.activ(self.conv_8(xd_7))
        
        xd_9 = self.pool_d(self.activ(self.conv_9(xd_8)))
        xd_10 = self.activ(self.conv_10(xd_9))
        
        print(xd_8.shape)
        print(xd_10.shape)
        print(torch.cat((xd_8, xd_10)).shape)

        # "Fractionally / Backward strided convolution" with activation and upsampling
        xu_1 = self.pool_u(self.activ(self.upconv_1(torch.cat((xd_8, xd_10), dim=2))))
        xu_2 = self.activ(self.upconv_2(xu_1))
        
        xu_3 = self.pool_u(self.activ(self.upconv_3(torch.cat((xd_6, xu_2), dim=1))))
        xu_4 = self.activ(self.upconv_4(xu_3))
        
        xu_5 = self.pool_u(self.activ(self.upconv_5(torch.cat((xd_4, xu_4), dim=1))))
        xu_6 = self.activ(self.upconv_6(xu_5))
        
        xu_7 = self.pool_u(self.activ(self.upconv_7(torch.cat((xd_2, xu_6), dim=1))))
        xu_8 = self.activ(self.upconv_8(xu_7))
        xu_9 = self.upconv_9(xu_8)
    
        return xu_9

model = ConvNet().to(device)

# %%
#criterion = nn.CrossEntropyLoss()# nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)

# %%
n_total_steps = len(train_loader)
for epoch in range(NBR_EPOCHS):
    for i, (images, labels) in tqdm(enumerate(train_loader)):
        # FORWARD PASS
        outputs = model(images)
        loss = F.binary_cross_entropy(outputs, labels)

        # BACKWARD PASS
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if (i) % 96 == 0:
            print (f'Epoch [{epoch+1}/{NBR_EPOCHS}], Step [{i+1}/{n_total_steps}], Loss: {loss.item():.4f}')

print('Finished Training')
# Out:
# 0it [00:10, ?it/s]
# torch.Size([10, 512, 19, 19])
# torch.Size([10, 1024, 6, 6])
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-44-3bd9b2571d10> in <module>
#       3     for i, (images, labels) in tqdm(enumerate(train_loader)):
#       4         # FORWARD PASS
# ----> 5         outputs = model(images)
#       6         loss = F.binary_cross_entropy(outputs, labels)
#       7
#
# ~/anaconda3/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# <ipython-input-42-19e40cf85766> in forward(self, x)
#      61         print(xd_8.shape)
# ...

# %%
root_dir = "../data/training/"
image_dir = root_dir + "images/"
to_tensor = T.ToTensor()
files = os.listdir(image_dir)
imgs = [(Image.open(image_dir + files[i])) for i in range(1)]
imgs[0]
