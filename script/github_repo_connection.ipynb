# %% [markdown]
# ## Update the GitHub Repository

# %%
# Import the drive and mount the remote directory
from google.colab import drive
drive.mount('/content/drive')

#Move to the directory
# %cd /content/drive/MyDrive/ml_epfl/ml_road_segmentation

# Parameters of the GitHub account
# !git config --global user.email "etienne.bruno@epfl.ch"
# !git config --global user.name "Etienne BRUNO from Colab"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/ml_epfl/ml_road_segmentation

# %%
# !git add .
# !git commit -m "Update from Google Colab"
# !git push
# Out:
# [main 9934120] Update from Google Colab
#  65 files changed, 13 insertions(+), 1069 deletions(-)
#  delete mode 100644 __pycache__/helper_functions.cpython-37.pyc
#  create mode 100644 data/predicted_test_set_images/test_001.png
#  create mode 100644 data/predicted_test_set_images/test_002.png
#  create mode 100644 data/predicted_test_set_images/test_003.png
#  create mode 100644 data/predicted_test_set_images/test_004.png
#  create mode 100644 data/predicted_test_set_images/test_005.png
#  create mode 100644 data/predicted_test_set_images/test_006.png
#  create mode 100644 data/predicted_test_set_images/test_007.png
#  create mode 100644 data/predicted_test_set_images/test_008.png
#  create mode 100644 data/predicted_test_set_images/test_009.png
#  create mode 100644 data/predicted_test_set_images/test_010.png
#  create mode 100644 data/predicted_test_set_images/test_011.png
#  create mode 100644 data/predicted_test_set_images/test_012.png
#  create mode 100644 data/predicted_test_set_images/test_013.png
#  create mode 100644 data/predicted_test_set_images/test_014.png
#  create mode 100644 data/predicted_test_set_images/test_015.png
#  create mode 100644 data/predicted_test_set_images/test_016.png
#  create mode 100644 data/predicted_test_set_images/test_017.png
#  create mode 100644 data/predicted_test_set_images/test_018.png
#  create mode 100644 data/predicted_test_set_images/test_019.png
#  create mode 100644 data/predicted_test_set_images/test_020.png
#  create mode 100644 data/predicted_test_set_images/test_021.png
#  create mode 100644 data/predicted_test_set_images/test_022.png
#  create mode 100644 data/predicted_test_set_images/test_023.png
#  create mode 100644 data/predicted_test_set_images/test_024.png
#  create mode 100644 data/predicted_test_set_images/test_025.png
#  create mode 100644 data/predicted_test_set_images/test_026.png
#  create mode 100644 data/predicted_test_set_images/test_027.png
#  create mode 100644 data/predicted_test_set_images/test_028.png
#  create mode 100644 data/predicted_test_set_images/test_029.png
#  create mode 100644 data/predicted_test_set_images/test_030.png
#  create mode 100644 data/predicted_test_set_images/test_031.png
#  create mode 100644 data/predicted_test_set_images/test_032.png
#  create mode 100644 data/predicted_test_set_images/test_033.png
#  create mode 100644 data/predicted_test_set_images/test_034.png
#  create mode 100644 data/predicted_test_set_images/test_035.png
#  create mode 100644 data/predicted_test_set_images/test_036.png
#  create mode 100644 data/predicted_test_set_images/test_037.png
#  create mode 100644 data/predicted_test_set_images/test_038.png
#  create mode 100644 data/predicted_test_set_images/test_039.png
#  create mode 100644 data/predicted_test_set_images/test_040.png
#  create mode 100644 data/predicted_test_set_images/test_041.png
#  create mode 100644 data/predicted_test_set_images/test_042.png
#  create mode 100644 data/predicted_test_set_images/test_043.png
#  create mode 100644 data/predicted_test_set_images/test_044.png
#  create mode 100644 data/predicted_test_set_images/test_045.png
#  create mode 100644 data/predicted_test_set_images/test_046.png
#  create mode 100644 data/predicted_test_set_images/test_047.png
#  create mode 100644 data/predicted_test_set_images/test_048.png
#  create mode 100644 data/predicted_test_set_images/test_049.png
#  create mode 100644 data/predicted_test_set_images/test_050.png
#  delete mode 100644 script/.ipynb_checkpoints/CNN-checkpoint.ipynb
#  delete mode 100644 script/.ipynb_checkpoints/segment_aerial_images-checkpoint.ipynb
#  delete mode 100644 script/__pycache__/dataset_loading.cpython-37.pyc
#  delete mode 100644 script/__pycache__/helper_functions.cpython-37.pyc
#  delete mode 100644 script/__pycache__/helper_functions.cpython-38.pyc
#  delete mode 100644 script/__pycache__/models.cpython-37.pyc
#  rewrite script/data_analysis.ipynb (84%)
#  delete mode 100644 script/data_savings.ipynb
#  delete mode 100644 script/prediction_u_net.ipynb
#  rewrite script/u-net.ipynb (99%)
#  delete mode 100644 script/u_net_k_fold.ipynb
#  delete mode 100644 script/u_net_train.ipynb
# Counting objects: 59, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (59/59), done.
# Writing objects: 100% (59/59), 180.65 KiB | 2.20 MiB/s, done.
# Total 59 (delta 5), reused 0 (delta 0)
# remote: Resolving deltas: 100% (5/5), completed with 5 local objects.
# To https://github.com/etiennebruno/cs433_project_2.git
#    2476691..9934120  main -> main
