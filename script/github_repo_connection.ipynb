# %% [markdown]
# ## Update the GitHub Repository

# %%
# Import the drive and mount the remote directory
from google.colab import drive
drive.mount('/content/drive')

#Move to the directory
# %cd /content/drive/MyDrive/ml_road_segmentation

# Parameters of the GitHub account
# !git config --global user.email "etienne.bruno@epfl.ch"
# !git config --global user.name "Etienne BRUNO from Colab"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/ml_road_segmentation

# %%
# !git add .
# !git commit -m "Update from Google Colab"
# !git push
# Out:
# [main e9cd8e3] Update from Google Colab
#  5 files changed, 2 insertions(+), 132 deletions(-)
#  delete mode 100644 github_repo_connection.ipynb
#  delete mode 100644 helper_functions.py
#  create mode 100644 script/github_repo_connection.ipynb
#  rewrite script/u_net.ipynb (94%)
# Counting objects: 7, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (7/7), done.
# Writing objects: 100% (7/7), 2.57 KiB | 439.00 KiB/s, done.
# Total 7 (delta 4), reused 0 (delta 0)
# remote: Resolving deltas: 100% (4/4), completed with 4 local objects.
# To https://github.com/etiennebruno/cs433_project_2.git
#    2d01be3..e9cd8e3  main -> main
