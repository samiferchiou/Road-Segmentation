# %% [markdown]
# ## Update the GitHub Repository

# %%
# Import the drive and mount the remote directory
from google.colab import drive
drive.mount('/content/drive')

#Move to the directory
# %cd /content/drive/MyDrive/ml_epfl/ml_road_segmentation

# Parameters of the GitHub account
# !git config --global user.email "etienne.bruno@epfl.ch"
# !git config --global user.name "Etienne BRUNO from Colab"
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/ml_epfl/ml_road_segmentation

# %%
# !git add .
# !git commit -m "Update from Google Colab"
# !git push
# Out:
# [main b127475] Update from Google Colab
#  56 files changed, 6 insertions(+), 6 deletions(-)
#  delete mode 100644 data/predicted_test_set_images/test_001.png
#  delete mode 100644 data/predicted_test_set_images/test_002.png
#  delete mode 100644 data/predicted_test_set_images/test_003.png
#  delete mode 100644 data/predicted_test_set_images/test_004.png
#  delete mode 100644 data/predicted_test_set_images/test_005.png
#  delete mode 100644 data/predicted_test_set_images/test_006.png
#  delete mode 100644 data/predicted_test_set_images/test_007.png
#  delete mode 100644 data/predicted_test_set_images/test_008.png
#  delete mode 100644 data/predicted_test_set_images/test_009.png
#  delete mode 100644 data/predicted_test_set_images/test_010.png
#  delete mode 100644 data/predicted_test_set_images/test_011.png
#  delete mode 100644 data/predicted_test_set_images/test_012.png
#  delete mode 100644 data/predicted_test_set_images/test_013.png
#  delete mode 100644 data/predicted_test_set_images/test_014.png
#  delete mode 100644 data/predicted_test_set_images/test_015.png
#  delete mode 100644 data/predicted_test_set_images/test_016.png
#  delete mode 100644 data/predicted_test_set_images/test_017.png
#  delete mode 100644 data/predicted_test_set_images/test_018.png
#  delete mode 100644 data/predicted_test_set_images/test_019.png
#  delete mode 100644 data/predicted_test_set_images/test_020.png
#  delete mode 100644 data/predicted_test_set_images/test_021.png
#  delete mode 100644 data/predicted_test_set_images/test_022.png
#  delete mode 100644 data/predicted_test_set_images/test_023.png
#  delete mode 100644 data/predicted_test_set_images/test_024.png
#  delete mode 100644 data/predicted_test_set_images/test_025.png
#  delete mode 100644 data/predicted_test_set_images/test_026.png
#  delete mode 100644 data/predicted_test_set_images/test_027.png
#  delete mode 100644 data/predicted_test_set_images/test_028.png
#  delete mode 100644 data/predicted_test_set_images/test_029.png
#  delete mode 100644 data/predicted_test_set_images/test_030.png
#  delete mode 100644 data/predicted_test_set_images/test_031.png
#  delete mode 100644 data/predicted_test_set_images/test_032.png
#  delete mode 100644 data/predicted_test_set_images/test_033.png
#  delete mode 100644 data/predicted_test_set_images/test_034.png
#  delete mode 100644 data/predicted_test_set_images/test_035.png
#  delete mode 100644 data/predicted_test_set_images/test_036.png
#  delete mode 100644 data/predicted_test_set_images/test_037.png
#  delete mode 100644 data/predicted_test_set_images/test_038.png
#  delete mode 100644 data/predicted_test_set_images/test_039.png
#  delete mode 100644 data/predicted_test_set_images/test_040.png
#  delete mode 100644 data/predicted_test_set_images/test_041.png
#  delete mode 100644 data/predicted_test_set_images/test_042.png
#  delete mode 100644 data/predicted_test_set_images/test_043.png
#  delete mode 100644 data/predicted_test_set_images/test_044.png
#  delete mode 100644 data/predicted_test_set_images/test_045.png
#  delete mode 100644 data/predicted_test_set_images/test_046.png
#  delete mode 100644 data/predicted_test_set_images/test_047.png
#  delete mode 100644 data/predicted_test_set_images/test_048.png
#  delete mode 100644 data/predicted_test_set_images/test_049.png
#  delete mode 100644 data/predicted_test_set_images/test_050.png
#  rewrite script/data_analysis.ipynb (84%)
#  rewrite script/prediction_u_net.ipynb (92%)
#  rewrite script/u_net_k_fold.ipynb (98%)
#  rewrite script/u_net_train_etienne.ipynb (80%)
#  rewrite script/u_net_train_sami.ipynb (63%)
# Counting objects: 10, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (10/10), done.
# Writing objects: 100% (10/10), 3.28 MiB | 4.98 MiB/s, done.
# Total 10 (delta 6), reused 0 (delta 0)
# remote: Resolving deltas: 100% (6/6), completed with 6 local objects.
# To https://github.com/etiennebruno/cs433_project_2.git
#    d353478..b127475  main -> main
