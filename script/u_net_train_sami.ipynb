# %% [markdown]
# ## MOUNT Google Drive

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !lscpu |grep 'Model name'
# !lscpu |grep 'Core(s) per socket:'
# !free -h
# !lscpu |grep 'Thread(s) per core'
# Out:
# Model name:          Intel(R) Xeon(R) CPU @ 2.30GHz
# Core(s) per socket:  4
#               total        used        free      shared  buff/cache   available
# Mem:            51G        878M         21G        1.2M         28G         49G
# Swap:            0B          0B          0B
# Thread(s) per core:  2

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Tue Dec 21 13:38:46 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   44C    P0    31W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ## IMPORTS

# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torch.optim.lr_scheduler import ExponentialLR
import numpy as np
import random
import os, sys, time
from PIL import Image
import torchvision.transforms as T
import scipy.ndimage as sc
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

sys.path.append('/content/drive/MyDrive/ml_epfl/ml_road_segmentation/script/')
#from helper_functions import *

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %% [markdown]
# ## CONSTANTS

# %%
CHECKPOINT_PATH ="/content/drive/MyDrive/ml_epfl/ml_road_segmentation/checkpoint/current_checkpoint_filter.pt"
BEST_MODEL_PATH ="/content/drive/MyDrive/ml_epfl/ml_road_segmentation/checkpoint/best_model_filter.pt"
NBR_EPOCHS = 100
BATCH_SIZE = 1
LEARNING_RATE = 1e-3
WEIGHT_DECAY = 1e-6
GAMMA = 0.99
K_FOLD = 4
VALIDATION_SET_IDX = 0
BATCH_SIZE_VAL = 5
SEED = 0

# %% [markdown]
# ## AUXILIARY FUNCTIONS

# %%
def format_time(seconds):
    return time.strftime("%H:%M:%S", time.gmtime(seconds))

# %%
def save_ckp(state, is_best, checkpoint_path, best_model_path):
    """
    state:            checkpoint we want to save
    is_best:          boolean to indicates if it is the best checkpoint
    checkpoint_path:  path to save checkpoint
    best_model_path:  path to save best model
    """
    torch.save(state, checkpoint_path)
    # if it is a best model, save the model's weights
    if is_best:
        torch.save(model.state_dict(), best_model_path)

# %%
def load_ckp(checkpoint_fpath, model, optimizer):
    """
    checkpoint_path: path to save checkpoint
    model:           model that we want to load checkpoint parameters into       
    optimizer:       optimizer we defined in previous training
    
    Return model, optimizer, scheduler, epoch value, f1 score
    """
    checkpoint = torch.load(checkpoint_fpath)
    # initialize state_dict from checkpoint to model
    model.load_state_dict(checkpoint['state_dict'])
    # initialize optimizer from checkpoint to optimizer
    optimizer.load_state_dict(checkpoint['optimizer'])
    # Get epoch number, f1_max, scheduler
    epoch = checkpoint['epoch']
    f1_max = checkpoint['f1_max']
    scheduler = checkpoint['scheduler']
    f1_validation = checkpoint['f1_validation']
    acc_validation = checkpoint['acc_validation']
    f1_training = checkpoint['scheduler']
    acc_training = checkpoint['acc_training']


    return model, optimizer, scheduler, epoch, f1_max, f1_validation, acc_validation, f1_training, acc_training

# %%
# FUNCTIONS FOR DATASET AUGMENTATION

#Constants
DIM_IMG = 400
DIM_IMG_CROP=DIM_IMG//2
NB_ROT = 0
ANGLE_ROTATION = 22.
SHARPNESS = 6
    
# Old Rotation
def rotation_old(imgs):
    rot_imgs = [T.functional.rotate(imgs[i], ANGLE_ROTATION*(idx_rot), expand=False)
                for idx_rot in range(NB_ROT)
                for i in range(len(imgs))
                ]
    return rot_imgs

# Rotation with mirroring
def rotation(imgs):
    rot_imgs = [torch.from_numpy(sc.rotate(imgs[i], ANGLE_ROTATION*(idx_rot+1), axes =(1,2), reshape=False, mode ='mirror'))
                for idx_rot in range(NB_ROT)
                for i in range(len(imgs))
               ]
    return rot_imgs

#Crop and resize
def crop(imgs):
    cropped_imgs = [T.Resize(size=DIM_IMG)(T.FiveCrop(size=DIM_IMG_CROP)(imgs[i])[tuple_i])
                    for tuple_i in range(5)
                    for i in range(len(imgs))
                   ]
    return cropped_imgs
#Adjust sharpness
def sharp(imgs):
    sharp_imgs = [T.functional.adjust_sharpness(imgs[i],SHARPNESS) 
                    for i in range(len(imgs))
                  ]
    return sharp_imgs

def compose_all_functions_for_data_X(imgs):
    #c = imgs + crop(imgs)
    #r = c + rotation(c)
    s = sharp(imgs)
    r = s + rotation(s)
    return r

def compose_all_functions_for_data_Y(imgs):
    #c = imgs + crop(imgs)
    #r = c + rotation(c)
    r = imgs + rotation(imgs)
    return r

def load_train_dataset():
    root_dir = "/content/drive/MyDrive/ml_epfl/ml_road_segmentation/data/training/"
    image_dir = root_dir + "images/"
    gt_dir = root_dir + "groundtruth/"
    files = os.listdir(image_dir)
    n = len(files)

    to_tensor = T.ToTensor()
    imgs = [to_tensor(Image.open(image_dir + files[i])) for i in range(n)]
    gt_imgs = [to_tensor(Image.open(gt_dir + files[i])) for i in range(n)]
    return (imgs, gt_imgs)

# %% [markdown]
# ## UNET MODEL

# %%
def double_conv(nbr_channels_in, nbr_channels_out):
    return nn.Sequential(
      nn.Conv2d(nbr_channels_in, nbr_channels_out, (3,3), padding=(1, 1)),
      nn.BatchNorm2d(nbr_channels_out),
      nn.ReLU(),
      nn.Conv2d(nbr_channels_out, nbr_channels_out, (3,3), padding=(1, 1)),
      nn.ReLU(),
      nn.BatchNorm2d(nbr_channels_out),
)


def one_step_up(x, x_d_i, pre_up_i, up_i):
    return up_i(torch.cat((pre_up_i(x), x_d_i), dim=1))


class u_net(nn.Module):
    def __init__(self):
        super(u_net, self).__init__()

        self.down_pooling = nn.MaxPool2d(2, 2)

        # Convolution Downwards
        self.down_1 = double_conv(3, 64) 
        self.down_2 = double_conv(64, 128)
        self.down_3 = double_conv(128, 256)
        self.down_4 = double_conv(256, 512)
        self.middle =  double_conv(512, 1024)
        
        # Upconvolution
        self.pre_up_1 = nn.ConvTranspose2d(1024, 512, (2, 2), (2, 2))
        self.up_1 = double_conv(512 + 512, 512)
                
        self.pre_up_2 = nn.ConvTranspose2d(512, 256, (2, 2), (2, 2))
        self.up_2 = double_conv(256 + 256, 256)
          
        self.pre_up_3 = nn.ConvTranspose2d(256, 128, (2, 2), (2, 2))
        self.up_3 = double_conv(128 + 128, 128)

        self.pre_up_4 = nn.ConvTranspose2d(128, 64, (2, 2), (2, 2))
        self.up_4 = double_conv(64 + 64, 64)

        self.final_convolution = nn.Conv2d(64, 2, (1,1))
        

    def forward(self, x):
        x_d_1 = self.down_1(x)
        x_d_2 = self.down_2(self.down_pooling(x_d_1))
        x_d_3 = self.down_3(self.down_pooling(x_d_2))
        x_d_4 = self.down_4(self.down_pooling(x_d_3))

        x = self.middle(self.down_pooling(x_d_4))

        x = one_step_up(x, x_d_4, self.pre_up_1, self.up_1)
        x = one_step_up(x, x_d_3, self.pre_up_2, self.up_2)
        x = one_step_up(x, x_d_2, self.pre_up_3, self.up_3)
        x = one_step_up(x, x_d_1, self.pre_up_4, self.up_4)
        
        return self.final_convolution(x)

# %% [markdown]
# ## DATASET LOADING

# %%
class imagesDataset(Dataset): 
    def __init__(self, K_fold, validation_set_idx, batch_size_val, seed):
        X, Y = load_train_dataset()

        #tresholding ground_truth values
        Y = [(y > 0.5).long() for y in Y]
        shape_y = Y[0].shape
        
        #shuffling
        random.seed(seed)
        idx_list = list(range(len(X)))
        random.shuffle(idx_list)
        random.seed()
        X = [X[idx] for idx in idx_list]
        Y = [Y[idx] for idx in idx_list]
        
        #K_fold separation
        fold_size = len(X) // K_fold
        start_validation_idx = validation_set_idx * fold_size
        end_validation_idx = start_validation_idx + fold_size
        self.X_train = X[slice(0, start_validation_idx)] + X[slice(end_validation_idx, None)]
        self.Y_train = Y[slice(0, start_validation_idx)] + Y[slice(end_validation_idx, None)]
        self.X_validation = X[slice(start_validation_idx, end_validation_idx)]
        self.Y_validation = Y[slice(start_validation_idx, end_validation_idx)]

        #data augmentation
        self.X_train = compose_all_functions_for_data_X(self.X_train)
        self.Y_train = compose_all_functions_for_data_Y(self.Y_train)
        self.X_validation = compose_all_functions_for_data_X(self.X_validation)
        self.Y_validation = compose_all_functions_for_data_Y(self.Y_validation)
        self.n_samples = len(self.X_train)

        #2nd shuffling
        random.seed(seed)
        idx_list = list(range(len(self.X_train)))
        random.shuffle(idx_list)
        random.seed()
        self.X_train = [self.X_train[idx] for idx in idx_list]
        self.Y_train = [self.Y_train[idx] for idx in idx_list]
        
        #casting into tensors
        self.X_train = torch.stack(self.X_train)
        self.X_validation = torch.stack(self.X_validation)
        self.Y_train = torch.reshape(torch.stack(self.Y_train) , (-1, shape_y[1], shape_y[2]))
        self.Y_validation = torch.reshape(torch.stack(self.Y_validation) , (-1, shape_y[1], shape_y[2]))

        #creating dataloader for validation data
        class dataset_validation(Dataset):
            def __init__(s,x,y):
                s.x = x
                s.y = y
                s.size = len(s.x)
            def __getitem__(s, index):
                return s.x[index], s.y[index]
            def __len__(s):
                return s.size
               
        self.validation_data_loader = torch.utils.data.DataLoader(
            dataset_validation(self.X_validation, self.Y_validation),
            batch_size = batch_size_val, shuffle = False)
        
        
    def __getitem__(self, index):
        return self.X_train[index], self.Y_train[index]

    def __len__(self):
        return self.n_samples
    
    def get_validation_dataloader(self):
        return self.validation_data_loader


dataset = imagesDataset(K_FOLD, VALIDATION_SET_IDX, BATCH_SIZE_VAL, SEED)
train_loader = torch.utils.data.DataLoader(dataset, batch_size = BATCH_SIZE, shuffle = True)
validation_dataloader = dataset.get_validation_dataloader()
print(len(dataset))
# Out:
# 75

# %% [markdown]
# ## TRAINING

# %%
def compute_scores(loader):
    #computing F1 score on validation data
    tp, fp, fn, tn = 0, 0, 0, 0
    for (data, target) in loader:
        data, target = data.to(device), target.to(device)
        with torch.no_grad():
            output = model(data)
        prediction = torch.argmax(output, dim = 1)
        confusions = prediction / target
        tp += torch.sum(confusions == 1).item()
        fp += torch.sum(confusions == float('inf')).item()
        fn += torch.sum(confusions == 0).item()
        tn += torch.sum(confusions == float("nan")).item()
    f1_score = 2 * tp / (2 * tp + fp + fn)
    accuracy = (tp + tn) / (tp + tn + fp+ fn)
    return f1_score, accuracy

# %%
def train(n_epochs, data_loader, model, optimizer, scheduler, criterion, device, checkpoint_path, best_model_path, f1_init):
    train_loader = data_loader
    validation_loader = train_loader.dataset.get_validation_dataloader()
    f1_max = f1_init
    
    save_f1_validation = []
    save_acc_validation = []
    save_f1_training = []
    save_acc_training = []

    for epoch in range(n_epochs):
        start_time_epoch = time.time()
        loss_list = []
        
        # Train the model for one epoch
        model.train()
        for (data, target) in train_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            loss = criterion(output, target)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            loss_list.append(loss.item())
        loss_epoch = np.mean(loss_list)

        model.eval()
        #computing scores on validation data
        f1_score_val, accuracy_score_val = compute_scores(validation_loader)
        save_f1_validation.append(f1_score_val)
        save_acc_validation.append(accuracy_score_val)

        #computing scores on training data
        f1_score_train, accuracy_score_train = compute_scores(train_loader)
        save_f1_training.append(f1_score_train)
        save_acc_training.append(accuracy_score_train)

        end_time_epoch = time.time()

        # Prepare saving of the model
        checkpoint = {
            'epoch': epoch,
            'f1_max': f1_max,
            'state_dict': model.state_dict(),
            'optimizer': optimizer.state_dict(),
            'scheduler': scheduler,
            'f1_validation' : save_f1_validation,
            'acc_validation' : save_acc_validation,
            'f1_training' : save_f1_training,
            'acc_training' : save_acc_training,
        }

        if f1_score_val > f1_max:
            save_ckp(checkpoint, True, checkpoint_path, best_model_path)
            f1_max = f1_score_val
        
        save_ckp(checkpoint, False, checkpoint_path, best_model_path)

        print(f"Epoch {epoch} || Loss:{loss_epoch:.6f} || Training F1 {f1_score_train:.6f} || Training Accuracy {accuracy_score_train:.6f} || Validation F1 {f1_score_val:.6f} || Validation Accuracy {accuracy_score_val:.6f} || Max F1 {f1_max:.6f} || LR {scheduler.get_last_lr()[0]:.6f} || Duration {format_time(end_time_epoch-start_time_epoch)}"+"\n")  
        scheduler.step()

# %%
LOAD_BEST_MODEL = False 
LOAD_LAST_CHECKPOINT = not LOAD_BEST_MODEL
COLD_START = True

# Declare UNET model, otimizer, adaptative learning rate and loss function
model =  u_net().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE, weight_decay=WEIGHT_DECAY)
scheduler = ExponentialLR(optimizer, GAMMA)
criterion = nn.CrossEntropyLoss()
f1_max = 0

if not COLD_START:
    if LOAD_LAST_CHECKPOINT and not LOAD_BEST_MODEL:
        model, optimizer, scheduler, epoch, f1_max, _ , _, _, _  = load_ckp(CHECKPOINT_PATH, model, optimizer)
    
    if not LOAD_LAST_CHECKPOINT and LOAD_BEST_MODEL:
        model.load_state_dict(torch.load(BEST_MODEL_PATH))

# %%
train(NBR_EPOCHS, train_loader, model, optimizer, scheduler, criterion, device, CHECKPOINT_PATH, BEST_MODEL_PATH, f1_max)
# Out:
# Epoch 0 || Loss:0.621143 || Training F1 0.557759 || Training Accuracy 0.386730 || Validation F1 0.570760 || Validation Accuracy 0.399345 || Max F1 0.570760 || LR 0.001000 || Duration 00:00:10
#
# Epoch 1 || Loss:0.449927 || Training F1 0.403521 || Training Accuracy 0.252757 || Validation F1 0.410841 || Validation Accuracy 0.258527 || Max F1 0.570760 || LR 0.000990 || Duration 00:00:10
#
# Epoch 2 || Loss:0.370892 || Training F1 0.626381 || Training Accuracy 0.456008 || Validation F1 0.621794 || Validation Accuracy 0.451162 || Max F1 0.621794 || LR 0.000980 || Duration 00:00:10
#
# Epoch 3 || Loss:0.340959 || Training F1 0.522798 || Training Accuracy 0.353911 || Validation F1 0.560640 || Validation Accuracy 0.389506 || Max F1 0.621794 || LR 0.000970 || Duration 00:00:10
#
# Epoch 4 || Loss:0.307997 || Training F1 0.670943 || Training Accuracy 0.504826 || Validation F1 0.687226 || Validation Accuracy 0.523492 || Max F1 0.687226 || LR 0.000961 || Duration 00:00:10
#
# Epoch 5 || Loss:0.292335 || Training F1 0.679993 || Training Accuracy 0.515144 || Validation F1 0.721008 || Validation Accuracy 0.563732 || Max F1 0.721008 || LR 0.000951 || Duration 00:00:10
#
# Epoch 6 || Loss:0.286385 || Training F1 0.663957 || Training Accuracy 0.496958 || Validation F1 0.681309 || Validation Accuracy 0.516656 || Max F1 0.721008 || LR 0.000941 || Duration 00:00:10
#
# Epoch 7 || Loss:0.270010 || Training F1 0.714875 || Training Accuracy 0.556269 || Validation F1 0.726720 || Validation Accuracy 0.570747 || Max F1 0.726720 || LR 0.000932 || Duration 00:00:10
#
# Epoch 8 || Loss:0.263800 || Training F1 0.580977 || Training Accuracy 0.409421 || Validation F1 0.638240 || Validation Accuracy 0.468687 || Max F1 0.726720 || LR 0.000923 || Duration 00:00:10
#
# Epoch 9 || Loss:0.263684 || Training F1 0.549534 || Training Accuracy 0.378867 || Validation F1 0.589237 || Validation Accuracy 0.417672 || Max F1 0.726720 || LR 0.000914 || Duration 00:00:10
#
# Epoch 10 || Loss:0.241341 || Training F1 0.720977 || Training Accuracy 0.563693 || Validation F1 0.761489 || Validation Accuracy 0.614843 || Max F1 0.761489 || LR 0.000904 || Duration 00:00:10
#
# Epoch 11 || Loss:0.224377 || Training F1 0.779866 || Training Accuracy 0.639165 || Validation F1 0.803506 || Validation Accuracy 0.671550 || Max F1 0.803506 || LR 0.000895 || Duration 00:00:10
#
# Epoch 12 || Loss:0.204761 || Training F1 0.768111 || Training Accuracy 0.623523 || Validation F1 0.772057 || Validation Accuracy 0.628740 || Max F1 0.803506 || LR 0.000886 || Duration 00:00:10
#
# Epoch 13 || Loss:0.198884 || Training F1 0.536418 || Training Accuracy 0.366510 || Validation F1 0.564874 || Validation Accuracy 0.393606 || Max F1 0.803506 || LR 0.000878 || Duration 00:00:10
#
# Epoch 14 || Loss:0.185516 || Training F1 0.770890 || Training Accuracy 0.627194 || Validation F1 0.748938 || Validation Accuracy 0.598642 || Max F1 0.803506 || LR 0.000869 || Duration 00:00:10
#
# Epoch 15 || Loss:0.184907 || Training F1 0.796370 || Training Accuracy 0.661640 || Validation F1 0.788468 || Validation Accuracy 0.650802 || Max F1 0.803506 || LR 0.000860 || Duration 00:00:10
#
# Epoch 16 || Loss:0.167581 || Training F1 0.835718 || Training Accuracy 0.717797 || Validation F1 0.810230 || Validation Accuracy 0.680997 || Max F1 0.810230 || LR 0.000851 || Duration 00:00:10
#
# Epoch 17 || Loss:0.159386 || Training F1 0.846733 || Training Accuracy 0.734203 || Validation F1 0.837465 || Validation Accuracy 0.720378 || Max F1 0.837465 || LR 0.000843 || Duration 00:00:10
#
# Epoch 18 || Loss:0.142623 || Training F1 0.849578 || Training Accuracy 0.738492 || Validation F1 0.831967 || Validation Accuracy 0.712281 || Max F1 0.837465 || LR 0.000835 || Duration 00:00:10
#
# Epoch 19 || Loss:0.132294 || Training F1 0.829151 || Training Accuracy 0.708162 || Validation F1 0.802583 || Validation Accuracy 0.670261 || Max F1 0.837465 || LR 0.000826 || Duration 00:00:10
#
# Epoch 20 || Loss:0.129092 || Training F1 0.830829 || Training Accuracy 0.710613 || Validation F1 0.825746 || Validation Accuracy 0.703210 || Max F1 0.837465 || LR 0.000818 || Duration 00:00:10
#
# Epoch 21 || Loss:0.130445 || Training F1 0.807066 || Training Accuracy 0.676538 || Validation F1 0.778262 || Validation Accuracy 0.637013 || Max F1 0.837465 || LR 0.000810 || Duration 00:00:10
#
# Epoch 22 || Loss:0.136229 || Training F1 0.641311 || Training Accuracy 0.472007 || Validation F1 0.582857 || Validation Accuracy 0.411290 || Max F1 0.837465 || LR 0.000802 || Duration 00:00:10
#
# Epoch 23 || Loss:0.128997 || Training F1 0.857023 || Training Accuracy 0.749816 || Validation F1 0.845100 || Validation Accuracy 0.731752 || Max F1 0.845100 || LR 0.000794 || Duration 00:00:10
#
# Epoch 24 || Loss:0.111778 || Training F1 0.872521 || Training Accuracy 0.773870 || Validation F1 0.855060 || Validation Accuracy 0.746816 || Max F1 0.855060 || LR 0.000786 || Duration 00:00:10
#
# Epoch 25 || Loss:0.102058 || Training F1 0.842772 || Training Accuracy 0.728267 || Validation F1 0.819866 || Validation Accuracy 0.694723 || Max F1 0.855060 || LR 0.000778 || Duration 00:00:10
#
# Epoch 26 || Loss:0.097334 || Training F1 0.819252 || Training Accuracy 0.693842 || Validation F1 0.834870 || Validation Accuracy 0.716547 || Max F1 0.855060 || LR 0.000770 || Duration 00:00:10
#
# Epoch 27 || Loss:0.097914 || Training F1 0.851189 || Training Accuracy 0.740930 || Validation F1 0.839712 || Validation Accuracy 0.723710 || Max F1 0.855060 || LR 0.000762 || Duration 00:00:10
#
# Epoch 28 || Loss:0.086952 || Training F1 0.873677 || Training Accuracy 0.775689 || Validation F1 0.841891 || Validation Accuracy 0.726953 || Max F1 0.855060 || LR 0.000755 || Duration 00:00:10
#
# Epoch 29 || Loss:0.082444 || Training F1 0.879559 || Training Accuracy 0.785012 || Validation F1 0.837347 || Validation Accuracy 0.720204 || Max F1 0.855060 || LR 0.000747 || Duration 00:00:10
#
# Epoch 30 || Loss:0.075415 || Training F1 0.882599 || Training Accuracy 0.789868 || Validation F1 0.844502 || Validation Accuracy 0.730856 || Max F1 0.855060 || LR 0.000740 || Duration 00:00:10
#
# Epoch 31 || Loss:0.096666 || Training F1 0.795436 || Training Accuracy 0.660351 || Validation F1 0.787277 || Validation Accuracy 0.649182 || Max F1 0.855060 || LR 0.000732 || Duration 00:00:10
#
# Epoch 32 || Loss:0.123431 || Training F1 0.855662 || Training Accuracy 0.747735 || Validation F1 0.814438 || Validation Accuracy 0.686964 || Max F1 0.855060 || LR 0.000725 || Duration 00:00:10
#
# Epoch 33 || Loss:0.091805 || Training F1 0.880985 || Training Accuracy 0.787285 || Validation F1 0.844619 || Validation Accuracy 0.731031 || Max F1 0.855060 || LR 0.000718 || Duration 00:00:10
#
# Epoch 34 || Loss:0.072848 || Training F1 0.904135 || Training Accuracy 0.825042 || Validation F1 0.866120 || Validation Accuracy 0.763855 || Max F1 0.866120 || LR 0.000711 || Duration 00:00:10
#
# Epoch 35 || Loss:0.065701 || Training F1 0.901071 || Training Accuracy 0.819953 || Validation F1 0.856668 || Validation Accuracy 0.749273 || Max F1 0.866120 || LR 0.000703 || Duration 00:00:10
#
# Epoch 36 || Loss:0.061088 || Training F1 0.889670 || Training Accuracy 0.801266 || Validation F1 0.848309 || Validation Accuracy 0.736577 || Max F1 0.866120 || LR 0.000696 || Duration 00:00:10
#
# Epoch 37 || Loss:0.060710 || Training F1 0.905930 || Training Accuracy 0.828037 || Validation F1 0.864275 || Validation Accuracy 0.760990 || Max F1 0.866120 || LR 0.000689 || Duration 00:00:10
#
# Epoch 38 || Loss:0.054995 || Training F1 0.902464 || Training Accuracy 0.822263 || Validation F1 0.862405 || Validation Accuracy 0.758095 || Max F1 0.866120 || LR 0.000683 || Duration 00:00:10
#
# Epoch 39 || Loss:0.052177 || Training F1 0.902370 || Training Accuracy 0.822107 || Validation F1 0.840272 || Validation Accuracy 0.724542 || Max F1 0.866120 || LR 0.000676 || Duration 00:00:10
#
# Epoch 40 || Loss:0.065547 || Training F1 0.873699 || Training Accuracy 0.775724 || Validation F1 0.844332 || Validation Accuracy 0.730602 || Max F1 0.866120 || LR 0.000669 || Duration 00:00:10
#
# Epoch 41 || Loss:0.061200 || Training F1 0.841586 || Training Accuracy 0.726498 || Validation F1 0.814672 || Validation Accuracy 0.687296 || Max F1 0.866120 || LR 0.000662 || Duration 00:00:10
#
# Epoch 42 || Loss:0.053507 || Training F1 0.898770 || Training Accuracy 0.816151 || Validation F1 0.840469 || Validation Accuracy 0.724836 || Max F1 0.866120 || LR 0.000656 || Duration 00:00:10
#
# Epoch 43 || Loss:0.056069 || Training F1 0.904661 || Training Accuracy 0.825918 || Validation F1 0.842533 || Validation Accuracy 0.727911 || Max F1 0.866120 || LR 0.000649 || Duration 00:00:10
#
# Epoch 44 || Loss:0.051608 || Training F1 0.897648 || Training Accuracy 0.814303 || Validation F1 0.869359 || Validation Accuracy 0.768908 || Max F1 0.869359 || LR 0.000643 || Duration 00:00:10
#
# Epoch 45 || Loss:0.046598 || Training F1 0.909343 || Training Accuracy 0.833757 || Validation F1 0.852872 || Validation Accuracy 0.743485 || Max F1 0.869359 || LR 0.000636 || Duration 00:00:10
#
# Epoch 46 || Loss:0.046111 || Training F1 0.891781 || Training Accuracy 0.804698 || Validation F1 0.854305 || Validation Accuracy 0.745665 || Max F1 0.869359 || LR 0.000630 || Duration 00:00:10
#
# Epoch 47 || Loss:0.043173 || Training F1 0.917779 || Training Accuracy 0.848052 || Validation F1 0.861316 || Validation Accuracy 0.756413 || Max F1 0.869359 || LR 0.000624 || Duration 00:00:10
#
# Epoch 48 || Loss:0.038267 || Training F1 0.916964 || Training Accuracy 0.846660 || Validation F1 0.855199 || Validation Accuracy 0.747028 || Max F1 0.869359 || LR 0.000617 || Duration 00:00:10
#
# Epoch 49 || Loss:0.041297 || Training F1 0.905026 || Training Accuracy 0.826527 || Validation F1 0.860969 || Validation Accuracy 0.755878 || Max F1 0.869359 || LR 0.000611 || Duration 00:00:10
#
# Epoch 50 || Loss:0.038623 || Training F1 0.907306 || Training Accuracy 0.830339 || Validation F1 0.867215 || Validation Accuracy 0.765560 || Max F1 0.869359 || LR 0.000605 || Duration 00:00:10
#
# Epoch 51 || Loss:0.037950 || Training F1 0.908224 || Training Accuracy 0.831877 || Validation F1 0.856232 || Validation Accuracy 0.748606 || Max F1 0.869359 || LR 0.000599 || Duration 00:00:10
#
# Epoch 52 || Loss:0.035336 || Training F1 0.904712 || Training Accuracy 0.826004 || Validation F1 0.853220 || Validation Accuracy 0.744014 || Max F1 0.869359 || LR 0.000593 || Duration 00:00:10
#
# Epoch 53 || Loss:0.033942 || Training F1 0.921365 || Training Accuracy 0.854195 || Validation F1 0.865431 || Validation Accuracy 0.762784 || Max F1 0.869359 || LR 0.000587 || Duration 00:00:10
#
# Epoch 54 || Loss:0.033342 || Training F1 0.910551 || Training Accuracy 0.835790 || Validation F1 0.866277 || Validation Accuracy 0.764099 || Max F1 0.869359 || LR 0.000581 || Duration 00:00:10
#
# Epoch 55 || Loss:0.031544 || Training F1 0.913299 || Training Accuracy 0.840432 || Validation F1 0.856583 || Validation Accuracy 0.749143 || Max F1 0.869359 || LR 0.000575 || Duration 00:00:10
#
# Epoch 56 || Loss:0.031626 || Training F1 0.911008 || Training Accuracy 0.836560 || Validation F1 0.855472 || Validation Accuracy 0.747446 || Max F1 0.869359 || LR 0.000570 || Duration 00:00:10
#
# Epoch 57 || Loss:0.034279 || Training F1 0.916279 || Training Accuracy 0.845494 || Validation F1 0.859598 || Validation Accuracy 0.753768 || Max F1 0.869359 || LR 0.000564 || Duration 00:00:10
#
# Epoch 58 || Loss:0.029925 || Training F1 0.918343 || Training Accuracy 0.849016 || Validation F1 0.862709 || Validation Accuracy 0.758564 || Max F1 0.869359 || LR 0.000558 || Duration 00:00:10
#
# Epoch 59 || Loss:0.033514 || Training F1 0.906480 || Training Accuracy 0.828957 || Validation F1 0.841795 || Validation Accuracy 0.726811 || Max F1 0.869359 || LR 0.000553 || Duration 00:00:10
#
# Epoch 60 || Loss:0.036578 || Training F1 0.873183 || Training Accuracy 0.774910 || Validation F1 0.835844 || Validation Accuracy 0.717983 || Max F1 0.869359 || LR 0.000547 || Duration 00:00:10
#
# Epoch 61 || Loss:0.038262 || Training F1 0.917359 || Training Accuracy 0.847334 || Validation F1 0.863394 || Validation Accuracy 0.759624 || Max F1 0.869359 || LR 0.000542 || Duration 00:00:10
#
# Epoch 62 || Loss:0.032165 || Training F1 0.925407 || Training Accuracy 0.861170 || Validation F1 0.864057 || Validation Accuracy 0.760652 || Max F1 0.869359 || LR 0.000536 || Duration 00:00:10
#
# Epoch 63 || Loss:0.025769 || Training F1 0.922409 || Training Accuracy 0.855991 || Validation F1 0.862374 || Validation Accuracy 0.758047 || Max F1 0.869359 || LR 0.000531 || Duration 00:00:10
#
# Epoch 64 || Loss:0.023499 || Training F1 0.917947 || Training Accuracy 0.848338 || Validation F1 0.872034 || Validation Accuracy 0.773104 || Max F1 0.872034 || LR 0.000526 || Duration 00:00:10
#
# Epoch 65 || Loss:0.025282 || Training F1 0.922706 || Training Accuracy 0.856504 || Validation F1 0.869440 || Validation Accuracy 0.769035 || Max F1 0.872034 || LR 0.000520 || Duration 00:00:10
#
# Epoch 66 || Loss:0.024349 || Training F1 0.917535 || Training Accuracy 0.847635 || Validation F1 0.868644 || Validation Accuracy 0.767790 || Max F1 0.872034 || LR 0.000515 || Duration 00:00:10
#
# Epoch 67 || Loss:0.022817 || Training F1 0.920104 || Training Accuracy 0.852031 || Validation F1 0.867635 || Validation Accuracy 0.766215 || Max F1 0.872034 || LR 0.000510 || Duration 00:00:10
#
# Epoch 68 || Loss:0.024936 || Training F1 0.929116 || Training Accuracy 0.867617 || Validation F1 0.862159 || Validation Accuracy 0.757715 || Max F1 0.872034 || LR 0.000505 || Duration 00:00:10
#
# Epoch 69 || Loss:0.027911 || Training F1 0.877014 || Training Accuracy 0.780965 || Validation F1 0.830153 || Validation Accuracy 0.709625 || Max F1 0.872034 || LR 0.000500 || Duration 00:00:10
#
# Epoch 70 || Loss:0.132334 || Training F1 0.834971 || Training Accuracy 0.716696 || Validation F1 0.827217 || Validation Accuracy 0.705345 || Max F1 0.872034 || LR 0.000495 || Duration 00:00:10
#
# Epoch 71 || Loss:0.094965 || Training F1 0.905317 || Training Accuracy 0.827013 || Validation F1 0.843565 || Validation Accuracy 0.729454 || Max F1 0.872034 || LR 0.000490 || Duration 00:00:10
#
# Epoch 72 || Loss:0.045160 || Training F1 0.920590 || Training Accuracy 0.852865 || Validation F1 0.859933 || Validation Accuracy 0.754283 || Max F1 0.872034 || LR 0.000485 || Duration 00:00:10
#
# Epoch 73 || Loss:0.032520 || Training F1 0.926843 || Training Accuracy 0.863660 || Validation F1 0.860502 || Validation Accuracy 0.755159 || Max F1 0.872034 || LR 0.000480 || Duration 00:00:10
#
# Epoch 74 || Loss:0.027161 || Training F1 0.929333 || Training Accuracy 0.867995 || Validation F1 0.855499 || Validation Accuracy 0.747487 || Max F1 0.872034 || LR 0.000475 || Duration 00:00:10
#
# Epoch 75 || Loss:0.022123 || Training F1 0.928778 || Training Accuracy 0.867026 || Validation F1 0.869177 || Validation Accuracy 0.768623 || Max F1 0.872034 || LR 0.000471 || Duration 00:00:10
#
# Epoch 76 || Loss:0.019154 || Training F1 0.934290 || Training Accuracy 0.876684 || Validation F1 0.870969 || Validation Accuracy 0.771431 || Max F1 0.872034 || LR 0.000466 || Duration 00:00:10
#
# Epoch 77 || Loss:0.018702 || Training F1 0.928485 || Training Accuracy 0.866516 || Validation F1 0.862391 || Validation Accuracy 0.758073 || Max F1 0.872034 || LR 0.000461 || Duration 00:00:10
#
# Epoch 78 || Loss:0.019236 || Training F1 0.934087 || Training Accuracy 0.876325 || Validation F1 0.864320 || Validation Accuracy 0.761060 || Max F1 0.872034 || LR 0.000457 || Duration 00:00:10
#
# Epoch 79 || Loss:0.022510 || Training F1 0.926071 || Training Accuracy 0.862320 || Validation F1 0.871215 || Validation Accuracy 0.771817 || Max F1 0.872034 || LR 0.000452 || Duration 00:00:10
#
# Epoch 80 || Loss:0.020710 || Training F1 0.935577 || Training Accuracy 0.878952 || Validation F1 0.865787 || Validation Accuracy 0.763338 || Max F1 0.872034 || LR 0.000448 || Duration 00:00:10
#
# Epoch 81 || Loss:0.020362 || Training F1 0.920823 || Training Accuracy 0.853264 || Validation F1 0.864888 || Validation Accuracy 0.761941 || Max F1 0.872034 || LR 0.000443 || Duration 00:00:10
#
# Epoch 82 || Loss:0.017893 || Training F1 0.934904 || Training Accuracy 0.877766 || Validation F1 0.858292 || Validation Accuracy 0.751761 || Max F1 0.872034 || LR 0.000439 || Duration 00:00:10
#
# Epoch 83 || Loss:0.015877 || Training F1 0.931813 || Training Accuracy 0.872331 || Validation F1 0.873802 || Validation Accuracy 0.775887 || Max F1 0.873802 || LR 0.000434 || Duration 00:00:10
#
# Epoch 84 || Loss:0.015671 || Training F1 0.923145 || Training Accuracy 0.857261 || Validation F1 0.868336 || Validation Accuracy 0.767310 || Max F1 0.873802 || LR 0.000430 || Duration 00:00:10
#
# Epoch 85 || Loss:0.016718 || Training F1 0.935399 || Training Accuracy 0.878637 || Validation F1 0.868172 || Validation Accuracy 0.767052 || Max F1 0.873802 || LR 0.000426 || Duration 00:00:10
#
# Epoch 86 || Loss:0.016871 || Training F1 0.936303 || Training Accuracy 0.880234 || Validation F1 0.867452 || Validation Accuracy 0.765930 || Max F1 0.873802 || LR 0.000421 || Duration 00:00:10
#
# Epoch 87 || Loss:0.017248 || Training F1 0.930042 || Training Accuracy 0.869233 || Validation F1 0.863376 || Validation Accuracy 0.759597 || Max F1 0.873802 || LR 0.000417 || Duration 00:00:10
#
# Epoch 88 || Loss:0.017902 || Training F1 0.930767 || Training Accuracy 0.870500 || Validation F1 0.871713 || Validation Accuracy 0.772598 || Max F1 0.873802 || LR 0.000413 || Duration 00:00:10
#
# Epoch 89 || Loss:0.017336 || Training F1 0.930546 || Training Accuracy 0.870113 || Validation F1 0.871326 || Validation Accuracy 0.771991 || Max F1 0.873802 || LR 0.000409 || Duration 00:00:10
#
# Epoch 90 || Loss:0.017770 || Training F1 0.928459 || Training Accuracy 0.866470 || Validation F1 0.870499 || Validation Accuracy 0.770693 || Max F1 0.873802 || LR 0.000405 || Duration 00:00:10
#
# Epoch 91 || Loss:0.015309 || Training F1 0.931703 || Training Accuracy 0.872138 || Validation F1 0.868906 || Validation Accuracy 0.768200 || Max F1 0.873802 || LR 0.000401 || Duration 00:00:10
#
# Epoch 92 || Loss:0.017137 || Training F1 0.936881 || Training Accuracy 0.881257 || Validation F1 0.868055 || Validation Accuracy 0.766871 || Max F1 0.873802 || LR 0.000397 || Duration 00:00:10
#
# Epoch 93 || Loss:0.016153 || Training F1 0.931760 || Training Accuracy 0.872238 || Validation F1 0.869629 || Validation Accuracy 0.769330 || Max F1 0.873802 || LR 0.000393 || Duration 00:00:10
#
# Epoch 94 || Loss:0.014417 || Training F1 0.936732 || Training Accuracy 0.880994 || Validation F1 0.870994 || Validation Accuracy 0.771470 || Max F1 0.873802 || LR 0.000389 || Duration 00:00:10
#
# Epoch 95 || Loss:0.014008 || Training F1 0.937400 || Training Accuracy 0.882176 || Validation F1 0.872542 || Validation Accuracy 0.773901 || Max F1 0.873802 || LR 0.000385 || Duration 00:00:10
#
# Epoch 96 || Loss:0.016028 || Training F1 0.937276 || Training Accuracy 0.881956 || Validation F1 0.869391 || Validation Accuracy 0.768958 || Max F1 0.873802 || LR 0.000381 || Duration 00:00:10
#
# Epoch 97 || Loss:0.015001 || Training F1 0.936951 || Training Accuracy 0.881381 || Validation F1 0.870054 || Validation Accuracy 0.769996 || Max F1 0.873802 || LR 0.000377 || Duration 00:00:10
#
# Epoch 98 || Loss:0.015822 || Training F1 0.933427 || Training Accuracy 0.875164 || Validation F1 0.869237 || Validation Accuracy 0.768717 || Max F1 0.873802 || LR 0.000373 || Duration 00:00:10
#
# Epoch 99 || Loss:0.017054 || Training F1 0.931404 || Training Accuracy 0.871615 || Validation F1 0.873825 || Validation Accuracy 0.775922 || Max F1 0.873825 || LR 0.000370 || Duration 00:00:10

# %% [markdown]
# ## TEST RESULTS

# %%
# Utilities
to_tensor = T.ToTensor() 
toPIL = T.ToPILImage()

DIM_IMG_TEST = 608

# %%
def load_test_dataset():
    root_test_dir = "/content/drive/MyDrive/ml_epfl/ml_road_segmentation/data/test_set_images/"
    test_i = 'test_'
    n = len(os.listdir(root_test_dir))
    test_imgs = [to_tensor(Image.open(root_test_dir + test_i + str(idx_img) +'/'+ test_i + str(idx_img) + '.png')).reshape((1, 3, DIM_IMG_TEST, DIM_IMG_TEST)) for idx_img in range(1, n+1)]
    test_imgs_filtered = sharp(test_imgs)
    return test_imgs_filtered
  
test_images = load_test_dataset()

# %%
def make_predictions(model, test_images):
    model.eval()
    predicted_images = [torch.argmax(model(img.to(device)), dim = 1).cpu().float() for img in test_images]
    return predicted_images

predictions = make_predictions(model, test_images)

# %%
plt.figure(figsize=(15,15))
IMG_INDEX = 47
images = [toPIL(test_images[IMG_INDEX].reshape((3, DIM_IMG_TEST, DIM_IMG_TEST))), toPIL(predictions[IMG_INDEX])]
for i, image in enumerate(images):
    plt.subplot(1, 2, i+1)
    plt.imshow(image)

# %%
plt.figure(figsize=(15,15))
IMG_INDEX = 45
images = [toPIL(test_images[IMG_INDEX].reshape((3, DIM_IMG_TEST, DIM_IMG_TEST))), toPIL(predictions[IMG_INDEX])]
for i, image in enumerate(images):
    plt.subplot(1, 2, i+1)
    plt.imshow(image)

# %% [markdown]
# ## JUST TO TRY ROTATION

# %%
# Just for testing
root_dir = "/content/drive/MyDrive/ml_epfl/ml_road_segmentation/data/training/images/"
files = os.listdir(root_dir)
to_tensor = T.ToTensor()
imgs = [to_tensor(Image.open(root_dir + files[i])) for i in range(1)]

ANGLE_ROTATION = 15
NB_ROT = 3
rot_imgs = imgs + [torch.from_numpy(sc.rotate(imgs[i], ANGLE_ROTATION*(idx_rot+1), axes =(1,2), reshape=False, mode="mirror")) for idx_rot in range(NB_ROT) for i in range(len(imgs)) ]

plt.figure(figsize=(25,25))
for i, image in enumerate(rot_imgs):
    plt.subplot(1, 4, i+1)
    plt.imshow(toPIL(image))
