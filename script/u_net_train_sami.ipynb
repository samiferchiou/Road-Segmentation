# %% [markdown]
# ## MOUNT Google Drive

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !lscpu |grep 'Model name'
# !lscpu |grep 'Core(s) per socket:'
# !free -h
# !lscpu |grep 'Thread(s) per core'
# Out:
# Model name:          Intel(R) Xeon(R) CPU @ 2.00GHz
# Core(s) per socket:  4
#               total        used        free      shared  buff/cache   available
# Mem:            51G        987M         47G        1.2M        2.1G         49G
# Swap:            0B          0B          0B
# Thread(s) per core:  2

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Wed Dec 22 12:56:53 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ## IMPORTS

# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torch.optim.lr_scheduler import ExponentialLR
import numpy as np
import random
import os, sys, time
from PIL import Image
import torchvision.transforms as T
import scipy.ndimage as sc
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

sys.path.append('/content/drive/MyDrive/ml_epfl/ml_road_segmentation/script/')
#from helper_functions import *

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %% [markdown]
# ## CONSTANTS

# %%
CHECKPOINT_PATH ="/content/drive/MyDrive/ml_epfl/ml_road_segmentation/checkpoint/current_checkpoint_filter.pt"
BEST_MODEL_PATH ="/content/drive/MyDrive/ml_epfl/ml_road_segmentation/checkpoint/best_model_filter.pt"
NBR_EPOCHS = 100
BATCH_SIZE = 1
LEARNING_RATE = 1e-3
WEIGHT_DECAY = 1e-6
GAMMA = 0.99
K_FOLD = 4
VALIDATION_SET_IDX = 0
BATCH_SIZE_VAL = 5
SEED = 0

# %% [markdown]
# ## AUXILIARY FUNCTIONS

# %%
def format_time(seconds):
    return time.strftime("%H:%M:%S", time.gmtime(seconds))

# %%
def save_ckp(state, is_best, checkpoint_path, best_model_path):
    """
    state:            checkpoint we want to save
    is_best:          boolean to indicates if it is the best checkpoint
    checkpoint_path:  path to save checkpoint
    best_model_path:  path to save best model
    """
    torch.save(state, checkpoint_path)
    # if it is a best model, save the model's weights
    if is_best:
        torch.save(model.state_dict(), best_model_path)

# %%
def load_ckp(checkpoint_fpath, model, optimizer):
    """
    checkpoint_path: path to save checkpoint
    model:           model that we want to load checkpoint parameters into       
    optimizer:       optimizer we defined in previous training
    
    Return model, optimizer, scheduler, epoch value, f1 score
    """
    checkpoint = torch.load(checkpoint_fpath)
    # initialize state_dict from checkpoint to model
    model.load_state_dict(checkpoint['state_dict'])
    # initialize optimizer from checkpoint to optimizer
    optimizer.load_state_dict(checkpoint['optimizer'])
    # Get epoch number, f1_max, scheduler
    epoch = checkpoint['epoch']
    f1_max = checkpoint['f1_max']
    scheduler = checkpoint['scheduler']
    f1_validation = checkpoint['f1_validation']
    acc_validation = checkpoint['acc_validation']
    f1_training = checkpoint['scheduler']
    acc_training = checkpoint['acc_training']


    return model, optimizer, scheduler, epoch, f1_max, f1_validation, acc_validation, f1_training, acc_training

# %%
# FUNCTIONS FOR DATASET AUGMENTATION

#Constants
DIM_IMG = 400
DIM_IMG_CROP=DIM_IMG//2
NB_ROT = 0
ANGLE_ROTATION = 22.
SHARPNESS = 5
CONTRAST = 0.75
    
# Old Rotation
def rotation_old(imgs):
    rot_imgs = [T.functional.rotate(imgs[i], ANGLE_ROTATION*(idx_rot), expand=False)
                for idx_rot in range(NB_ROT)
                for i in range(len(imgs))
                ]
    return rot_imgs

# Rotation with mirroring
def rotation(imgs):
    rot_imgs = [torch.from_numpy(sc.rotate(imgs[i], ANGLE_ROTATION*(idx_rot+1), axes =(1,2), reshape=False, mode ='mirror'))
                for idx_rot in range(NB_ROT)
                for i in range(len(imgs))
               ]
    return rot_imgs

#Crop and resize
def crop(imgs):
    cropped_imgs = [T.Resize(size=DIM_IMG)(T.FiveCrop(size=DIM_IMG_CROP)(imgs[i])[tuple_i])
                    for tuple_i in range(5)
                    for i in range(len(imgs))
                   ]
    return cropped_imgs

#Adjust sharpness
def sharp(imgs):
    sharp_imgs = [T.functional.adjust_sharpness(imgs[i],SHARPNESS) 
                    for i in range(len(imgs))
                  ]
    return sharp_imgs


#Adjust contrast
def contrast(imgs):
    contrast_imgs = [T.functional.adjust_contrast(imgs[i],CONTRAST) 
                    for i in range(len(imgs))
                  ]
    return contrast_imgs

def compose_all_functions_for_data_X(imgs):
    #c = imgs + crop(imgs)
    #r = c + rotation(c)
    s = sharp(imgs)
    c = contrast(s)
    r = c + rotation(c)
    return r

def compose_all_functions_for_data_Y(imgs):
    #c = imgs + crop(imgs)
    #r = c + rotation(c)
    r = imgs + rotation(imgs)
    return r

def load_train_dataset():
    root_dir = "/content/drive/MyDrive/ml_epfl/ml_road_segmentation/data/training/"
    image_dir = root_dir + "images/"
    gt_dir = root_dir + "groundtruth/"
    files = os.listdir(image_dir)
    n = len(files)

    to_tensor = T.ToTensor()
    imgs = [to_tensor(Image.open(image_dir + files[i])) for i in range(n)]
    gt_imgs = [to_tensor(Image.open(gt_dir + files[i])) for i in range(n)]
    return (imgs, gt_imgs)

# %% [markdown]
# ## UNET MODEL

# %%
def double_conv(nbr_channels_in, nbr_channels_out):
    return nn.Sequential(
      nn.Conv2d(nbr_channels_in, nbr_channels_out, (3,3), padding=(1, 1)),
      nn.BatchNorm2d(nbr_channels_out),
      nn.ReLU(),
      nn.Conv2d(nbr_channels_out, nbr_channels_out, (3,3), padding=(1, 1)),
      nn.ReLU(),
      nn.BatchNorm2d(nbr_channels_out),
)


def one_step_up(x, x_d_i, pre_up_i, up_i):
    return up_i(torch.cat((pre_up_i(x), x_d_i), dim=1))


class u_net(nn.Module):
    def __init__(self):
        super(u_net, self).__init__()

        self.down_pooling = nn.MaxPool2d(2, 2)

        # Convolution Downwards
        self.down_1 = double_conv(3, 64) 
        self.down_2 = double_conv(64, 128)
        self.down_3 = double_conv(128, 256)
        self.down_4 = double_conv(256, 512)
        self.middle =  double_conv(512, 1024)
        
        # Upconvolution
        self.pre_up_1 = nn.ConvTranspose2d(1024, 512, (2, 2), (2, 2))
        self.up_1 = double_conv(512 + 512, 512)
                
        self.pre_up_2 = nn.ConvTranspose2d(512, 256, (2, 2), (2, 2))
        self.up_2 = double_conv(256 + 256, 256)
          
        self.pre_up_3 = nn.ConvTranspose2d(256, 128, (2, 2), (2, 2))
        self.up_3 = double_conv(128 + 128, 128)

        self.pre_up_4 = nn.ConvTranspose2d(128, 64, (2, 2), (2, 2))
        self.up_4 = double_conv(64 + 64, 64)

        self.final_convolution = nn.Conv2d(64, 2, (1,1))
        

    def forward(self, x):
        x_d_1 = self.down_1(x)
        x_d_2 = self.down_2(self.down_pooling(x_d_1))
        x_d_3 = self.down_3(self.down_pooling(x_d_2))
        x_d_4 = self.down_4(self.down_pooling(x_d_3))

        x = self.middle(self.down_pooling(x_d_4))

        x = one_step_up(x, x_d_4, self.pre_up_1, self.up_1)
        x = one_step_up(x, x_d_3, self.pre_up_2, self.up_2)
        x = one_step_up(x, x_d_2, self.pre_up_3, self.up_3)
        x = one_step_up(x, x_d_1, self.pre_up_4, self.up_4)
        
        return self.final_convolution(x)

# %% [markdown]
# ## DATASET LOADING

# %%
class imagesDataset(Dataset): 
    def __init__(self, K_fold, validation_set_idx, batch_size_val, seed):
        X, Y = load_train_dataset()

        #tresholding ground_truth values
        Y = [(y > 0.5).long() for y in Y]
        shape_y = Y[0].shape
        
        #shuffling
        random.seed(seed)
        idx_list = list(range(len(X)))
        random.shuffle(idx_list)
        random.seed()
        X = [X[idx] for idx in idx_list]
        Y = [Y[idx] for idx in idx_list]
        
        #K_fold separation
        fold_size = len(X) // K_fold
        start_validation_idx = validation_set_idx * fold_size
        end_validation_idx = start_validation_idx + fold_size
        self.X_train = X[slice(0, start_validation_idx)] + X[slice(end_validation_idx, None)]
        self.Y_train = Y[slice(0, start_validation_idx)] + Y[slice(end_validation_idx, None)]
        self.X_validation = X[slice(start_validation_idx, end_validation_idx)]
        self.Y_validation = Y[slice(start_validation_idx, end_validation_idx)]

        #data augmentation
        self.X_train = compose_all_functions_for_data_X(self.X_train)
        self.Y_train = compose_all_functions_for_data_Y(self.Y_train)
        self.X_validation = compose_all_functions_for_data_X(self.X_validation)
        self.Y_validation = compose_all_functions_for_data_Y(self.Y_validation)
        self.n_samples = len(self.X_train)

        #2nd shuffling
        random.seed(seed)
        idx_list = list(range(len(self.X_train)))
        random.shuffle(idx_list)
        random.seed()
        self.X_train = [self.X_train[idx] for idx in idx_list]
        self.Y_train = [self.Y_train[idx] for idx in idx_list]
        
        #casting into tensors
        self.X_train = torch.stack(self.X_train)
        self.X_validation = torch.stack(self.X_validation)
        self.Y_train = torch.reshape(torch.stack(self.Y_train) , (-1, shape_y[1], shape_y[2]))
        self.Y_validation = torch.reshape(torch.stack(self.Y_validation) , (-1, shape_y[1], shape_y[2]))

        #creating dataloader for validation data
        class dataset_validation(Dataset):
            def __init__(s,x,y):
                s.x = x
                s.y = y
                s.size = len(s.x)
            def __getitem__(s, index):
                return s.x[index], s.y[index]
            def __len__(s):
                return s.size
               
        self.validation_data_loader = torch.utils.data.DataLoader(
            dataset_validation(self.X_validation, self.Y_validation),
            batch_size = batch_size_val, shuffle = False)
        
        
    def __getitem__(self, index):
        return self.X_train[index], self.Y_train[index]

    def __len__(self):
        return self.n_samples
    
    def get_validation_dataloader(self):
        return self.validation_data_loader


dataset = imagesDataset(K_FOLD, VALIDATION_SET_IDX, BATCH_SIZE_VAL, SEED)
train_loader = torch.utils.data.DataLoader(dataset, batch_size = BATCH_SIZE, shuffle = True)
validation_dataloader = dataset.get_validation_dataloader()
print(len(dataset))
# Out:
# 75

# %%
#VERIFYING THE FILTERING

to_tensor = T.ToTensor() 
toPIL = T.ToPILImage()
idx_image = 2
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(25, 35))
ax1.imshow(toPIL(dataset.X_train[idx_image]))
ax2.imshow(toPIL(torch.from_numpy(sc.rotate(dataset.X_train[idx_image], ANGLE_ROTATION*2, axes =(1,2), reshape=False))))
ax3.imshow(toPIL(torch.from_numpy(sc.rotate(dataset.X_train[idx_image], ANGLE_ROTATION*2, axes =(1,2), reshape=False, mode ='mirror'))))

ax1.set_title("Original image")
ax2.set_title(f"Image rotated")
ax3.set_title(f"Image rotated and mirrored")
# Out:
# Text(0.5, 1.0, 'Image rotated and mirrored')

# %% [markdown]
# ## TRAINING

# %%
def compute_scores(loader):
    #computing F1 score on validation data
    tp, fp, fn, tn = 0, 0, 0, 0
    for (data, target) in loader:
        data, target = data.to(device), target.to(device)
        with torch.no_grad():
            output = model(data)
        prediction = torch.argmax(output, dim = 1)
        confusions = prediction / target
        tp += torch.sum(confusions == 1).item()
        fp += torch.sum(confusions == float('inf')).item()
        fn += torch.sum(confusions == 0).item()
        tn += torch.sum(confusions == float("nan")).item()
    f1_score = 2 * tp / (2 * tp + fp + fn)
    accuracy = (tp + tn) / (tp + tn + fp+ fn)
    return f1_score, accuracy

# %%
def train(n_epochs, data_loader, model, optimizer, scheduler, criterion, device, checkpoint_path, best_model_path, f1_init):
    train_loader = data_loader
    validation_loader = train_loader.dataset.get_validation_dataloader()
    f1_max = f1_init
    
    save_f1_validation = []
    save_acc_validation = []
    save_f1_training = []
    save_acc_training = []

    for epoch in range(n_epochs):
        start_time_epoch = time.time()
        loss_list = []
        
        # Train the model for one epoch
        model.train()
        for (data, target) in train_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            loss = criterion(output, target)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            loss_list.append(loss.item())
        loss_epoch = np.mean(loss_list)

        model.eval()
        #computing scores on validation data
        f1_score_val, accuracy_score_val = compute_scores(validation_loader)
        save_f1_validation.append(f1_score_val)
        save_acc_validation.append(accuracy_score_val)

        #computing scores on training data
        f1_score_train, accuracy_score_train = compute_scores(train_loader)
        save_f1_training.append(f1_score_train)
        save_acc_training.append(accuracy_score_train)

        end_time_epoch = time.time()

        # Prepare saving of the model
        checkpoint = {
            'epoch': epoch,
            'f1_max': f1_max,
            'state_dict': model.state_dict(),
            'optimizer': optimizer.state_dict(),
            'scheduler': scheduler,
            'f1_validation' : save_f1_validation,
            'acc_validation' : save_acc_validation,
            'f1_training' : save_f1_training,
            'acc_training' : save_acc_training,
        }

        if f1_score_val > f1_max:
            save_ckp(checkpoint, True, checkpoint_path, best_model_path)
            f1_max = f1_score_val
        
        save_ckp(checkpoint, False, checkpoint_path, best_model_path)

        print(f"Epoch {epoch} || Loss:{loss_epoch:.6f} || Training F1 {f1_score_train:.6f} || Training Accuracy {accuracy_score_train:.6f} || Validation F1 {f1_score_val:.6f} || Validation Accuracy {accuracy_score_val:.6f} || Max F1 {f1_max:.6f} || LR {scheduler.get_last_lr()[0]:.6f} || Duration {format_time(end_time_epoch-start_time_epoch)}"+"\n")  
        scheduler.step()

# %%
LOAD_BEST_MODEL = False 
LOAD_LAST_CHECKPOINT = not LOAD_BEST_MODEL
COLD_START = True

# Declare UNET model, otimizer, adaptative learning rate and loss function
model =  u_net().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE, weight_decay=WEIGHT_DECAY)
scheduler = ExponentialLR(optimizer, GAMMA)
criterion = nn.CrossEntropyLoss()
f1_max = 0

if not COLD_START:
    if LOAD_LAST_CHECKPOINT and not LOAD_BEST_MODEL:
        model, optimizer, scheduler, epoch, f1_max, _ , _, _, _  = load_ckp(CHECKPOINT_PATH, model, optimizer)
    
    if not LOAD_LAST_CHECKPOINT and LOAD_BEST_MODEL:
        model.load_state_dict(torch.load(BEST_MODEL_PATH))

# %%
train(NBR_EPOCHS, train_loader, model, optimizer, scheduler, criterion, device, CHECKPOINT_PATH, BEST_MODEL_PATH, f1_max)
# Out:
# Epoch 0 || Loss:0.628292 || Training F1 0.418466 || Training Accuracy 0.264595 || Validation F1 0.433999 || Validation Accuracy 0.277139 || Max F1 0.433999 || LR 0.001000 || Duration 00:00:10
#
# Epoch 1 || Loss:0.442471 || Training F1 0.570397 || Training Accuracy 0.398990 || Validation F1 0.583383 || Validation Accuracy 0.411815 || Max F1 0.583383 || LR 0.000990 || Duration 00:00:10
#
# Epoch 2 || Loss:0.356208 || Training F1 0.588538 || Training Accuracy 0.416971 || Validation F1 0.627998 || Validation Accuracy 0.457724 || Max F1 0.627998 || LR 0.000980 || Duration 00:00:10
#
# Epoch 3 || Loss:0.332588 || Training F1 0.563121 || Training Accuracy 0.391906 || Validation F1 0.572768 || Validation Accuracy 0.401314 || Max F1 0.627998 || LR 0.000970 || Duration 00:00:10
#
# Epoch 4 || Loss:0.304418 || Training F1 0.487299 || Training Accuracy 0.322138 || Validation F1 0.400627 || Validation Accuracy 0.250490 || Max F1 0.627998 || LR 0.000961 || Duration 00:00:10
#
# Epoch 5 || Loss:0.289577 || Training F1 0.314925 || Training Accuracy 0.186891 || Validation F1 0.265007 || Validation Accuracy 0.152742 || Max F1 0.627998 || LR 0.000951 || Duration 00:00:10
#
# Epoch 6 || Loss:0.280634 || Training F1 0.526166 || Training Accuracy 0.357005 || Validation F1 0.551251 || Validation Accuracy 0.380502 || Max F1 0.627998 || LR 0.000941 || Duration 00:00:10
#
# Epoch 7 || Loss:0.255092 || Training F1 0.109882 || Training Accuracy 0.058135 || Validation F1 0.053381 || Validation Accuracy 0.027422 || Max F1 0.627998 || LR 0.000932 || Duration 00:00:10
#
# Epoch 8 || Loss:0.245634 || Training F1 0.750400 || Training Accuracy 0.600512 || Validation F1 0.753534 || Validation Accuracy 0.604536 || Max F1 0.753534 || LR 0.000923 || Duration 00:00:10
#
# Epoch 9 || Loss:0.225192 || Training F1 0.747751 || Training Accuracy 0.597127 || Validation F1 0.759750 || Validation Accuracy 0.612579 || Max F1 0.759750 || LR 0.000914 || Duration 00:00:10
#
# Epoch 10 || Loss:0.208238 || Training F1 0.763321 || Training Accuracy 0.617235 || Validation F1 0.796949 || Validation Accuracy 0.662440 || Max F1 0.796949 || LR 0.000904 || Duration 00:00:10
#
# Epoch 11 || Loss:0.201684 || Training F1 0.759001 || Training Accuracy 0.611605 || Validation F1 0.770176 || Validation Accuracy 0.626248 || Max F1 0.796949 || LR 0.000895 || Duration 00:00:10
#
# Epoch 12 || Loss:0.178917 || Training F1 0.759497 || Training Accuracy 0.612249 || Validation F1 0.792275 || Validation Accuracy 0.656006 || Max F1 0.796949 || LR 0.000886 || Duration 00:00:10
#
# Epoch 13 || Loss:0.178802 || Training F1 0.777420 || Training Accuracy 0.635885 || Validation F1 0.755350 || Validation Accuracy 0.606877 || Max F1 0.796949 || LR 0.000878 || Duration 00:00:10
#
# Epoch 14 || Loss:0.176060 || Training F1 0.753986 || Training Accuracy 0.605118 || Validation F1 0.748605 || Validation Accuracy 0.598216 || Max F1 0.796949 || LR 0.000869 || Duration 00:00:10
#
# Epoch 15 || Loss:0.153808 || Training F1 0.721364 || Training Accuracy 0.564167 || Validation F1 0.727932 || Validation Accuracy 0.572243 || Max F1 0.796949 || LR 0.000860 || Duration 00:00:10
#
# Epoch 16 || Loss:0.195492 || Training F1 0.755899 || Training Accuracy 0.607587 || Validation F1 0.749069 || Validation Accuracy 0.598810 || Max F1 0.796949 || LR 0.000851 || Duration 00:00:10
#
# Epoch 17 || Loss:0.199873 || Training F1 0.648564 || Training Accuracy 0.479907 || Validation F1 0.637455 || Validation Accuracy 0.467841 || Max F1 0.796949 || LR 0.000843 || Duration 00:00:10
#
# Epoch 18 || Loss:0.158793 || Training F1 0.809638 || Training Accuracy 0.680162 || Validation F1 0.805583 || Validation Accuracy 0.674457 || Max F1 0.805583 || LR 0.000835 || Duration 00:00:10
#
# Epoch 19 || Loss:0.132200 || Training F1 0.833595 || Training Accuracy 0.714670 || Validation F1 0.823327 || Validation Accuracy 0.699707 || Max F1 0.823327 || LR 0.000826 || Duration 00:00:10
#
# Epoch 20 || Loss:0.117218 || Training F1 0.786321 || Training Accuracy 0.647883 || Validation F1 0.793933 || Validation Accuracy 0.658282 || Max F1 0.823327 || LR 0.000818 || Duration 00:00:10
#
# Epoch 21 || Loss:0.107395 || Training F1 0.829653 || Training Accuracy 0.708894 || Validation F1 0.799946 || Validation Accuracy 0.666592 || Max F1 0.823327 || LR 0.000810 || Duration 00:00:10
#
# Epoch 22 || Loss:0.101333 || Training F1 0.826238 || Training Accuracy 0.703922 || Validation F1 0.822282 || Validation Accuracy 0.698199 || Max F1 0.823327 || LR 0.000802 || Duration 00:00:10
#
# Epoch 23 || Loss:0.106730 || Training F1 0.598392 || Training Accuracy 0.426933 || Validation F1 0.600473 || Validation Accuracy 0.429054 || Max F1 0.823327 || LR 0.000794 || Duration 00:00:10
#
# Epoch 24 || Loss:0.120992 || Training F1 0.860095 || Training Accuracy 0.754531 || Validation F1 0.824101 || Validation Accuracy 0.700826 || Max F1 0.824101 || LR 0.000786 || Duration 00:00:10
#
# Epoch 25 || Loss:0.094633 || Training F1 0.592265 || Training Accuracy 0.420722 || Validation F1 0.626875 || Validation Accuracy 0.456531 || Max F1 0.824101 || LR 0.000778 || Duration 00:00:10
#
# Epoch 26 || Loss:0.084725 || Training F1 0.862974 || Training Accuracy 0.758975 || Validation F1 0.831664 || Validation Accuracy 0.711837 || Max F1 0.831664 || LR 0.000770 || Duration 00:00:10
#
# Epoch 27 || Loss:0.079101 || Training F1 0.851976 || Training Accuracy 0.742124 || Validation F1 0.826523 || Validation Accuracy 0.704337 || Max F1 0.831664 || LR 0.000762 || Duration 00:00:10
#
# Epoch 28 || Loss:0.071818 || Training F1 0.843350 || Training Accuracy 0.729131 || Validation F1 0.833764 || Validation Accuracy 0.714919 || Max F1 0.833764 || LR 0.000755 || Duration 00:00:10
#
# Epoch 29 || Loss:0.065634 || Training F1 0.864668 || Training Accuracy 0.761600 || Validation F1 0.830612 || Validation Accuracy 0.710297 || Max F1 0.833764 || LR 0.000747 || Duration 00:00:10
#
# Epoch 30 || Loss:0.069186 || Training F1 0.814808 || Training Accuracy 0.687490 || Validation F1 0.787991 || Validation Accuracy 0.650153 || Max F1 0.833764 || LR 0.000740 || Duration 00:00:10
#
# Epoch 31 || Loss:0.064090 || Training F1 0.872056 || Training Accuracy 0.773137 || Validation F1 0.840041 || Validation Accuracy 0.724198 || Max F1 0.840041 || LR 0.000732 || Duration 00:00:10
#
# Epoch 32 || Loss:0.064068 || Training F1 0.860316 || Training Accuracy 0.754873 || Validation F1 0.832563 || Validation Accuracy 0.713155 || Max F1 0.840041 || LR 0.000725 || Duration 00:00:10
#
# Epoch 33 || Loss:0.060383 || Training F1 0.830351 || Training Accuracy 0.709914 || Validation F1 0.797646 || Validation Accuracy 0.663404 || Max F1 0.840041 || LR 0.000718 || Duration 00:00:10
#
# Epoch 34 || Loss:0.057774 || Training F1 0.867402 || Training Accuracy 0.765851 || Validation F1 0.829382 || Validation Accuracy 0.708500 || Max F1 0.840041 || LR 0.000711 || Duration 00:00:10
#
# Epoch 35 || Loss:0.055548 || Training F1 0.842559 || Training Accuracy 0.727950 || Validation F1 0.835042 || Validation Accuracy 0.716800 || Max F1 0.840041 || LR 0.000703 || Duration 00:00:10
#
# Epoch 36 || Loss:0.048927 || Training F1 0.867446 || Training Accuracy 0.765920 || Validation F1 0.827580 || Validation Accuracy 0.705873 || Max F1 0.840041 || LR 0.000696 || Duration 00:00:10
#
# Epoch 37 || Loss:0.048127 || Training F1 0.755103 || Training Accuracy 0.606558 || Validation F1 0.775952 || Validation Accuracy 0.633923 || Max F1 0.840041 || LR 0.000689 || Duration 00:00:10
#
# Epoch 38 || Loss:0.045413 || Training F1 0.832339 || Training Accuracy 0.712827 || Validation F1 0.777961 || Validation Accuracy 0.636609 || Max F1 0.840041 || LR 0.000683 || Duration 00:00:10
#
# Epoch 39 || Loss:0.047184 || Training F1 0.851438 || Training Accuracy 0.741309 || Validation F1 0.823651 || Validation Accuracy 0.700175 || Max F1 0.840041 || LR 0.000676 || Duration 00:00:10
#
# Epoch 40 || Loss:0.045123 || Training F1 0.887212 || Training Accuracy 0.797288 || Validation F1 0.854338 || Validation Accuracy 0.745716 || Max F1 0.854338 || LR 0.000669 || Duration 00:00:10
#
# Epoch 41 || Loss:0.046636 || Training F1 0.872640 || Training Accuracy 0.774057 || Validation F1 0.832894 || Validation Accuracy 0.713640 || Max F1 0.854338 || LR 0.000662 || Duration 00:00:10
#
# Epoch 42 || Loss:0.043302 || Training F1 0.874477 || Training Accuracy 0.776952 || Validation F1 0.827899 || Validation Accuracy 0.706338 || Max F1 0.854338 || LR 0.000656 || Duration 00:00:10
#
# Epoch 43 || Loss:0.037277 || Training F1 0.895908 || Training Accuracy 0.811443 || Validation F1 0.844523 || Validation Accuracy 0.730887 || Max F1 0.854338 || LR 0.000649 || Duration 00:00:10
#
# Epoch 44 || Loss:0.033729 || Training F1 0.874392 || Training Accuracy 0.776817 || Validation F1 0.830543 || Validation Accuracy 0.710195 || Max F1 0.854338 || LR 0.000643 || Duration 00:00:10
#
# Epoch 45 || Loss:0.033314 || Training F1 0.861451 || Training Accuracy 0.756622 || Validation F1 0.817064 || Validation Accuracy 0.690709 || Max F1 0.854338 || LR 0.000636 || Duration 00:00:10
#
# Epoch 46 || Loss:0.033025 || Training F1 0.895384 || Training Accuracy 0.810585 || Validation F1 0.840657 || Validation Accuracy 0.725115 || Max F1 0.854338 || LR 0.000630 || Duration 00:00:10
#
# Epoch 47 || Loss:0.031897 || Training F1 0.865012 || Training Accuracy 0.762133 || Validation F1 0.807059 || Validation Accuracy 0.676529 || Max F1 0.854338 || LR 0.000624 || Duration 00:00:10
#
# Epoch 48 || Loss:0.030866 || Training F1 0.883313 || Training Accuracy 0.791012 || Validation F1 0.834551 || Validation Accuracy 0.716077 || Max F1 0.854338 || LR 0.000617 || Duration 00:00:10
#
# Epoch 49 || Loss:0.029726 || Training F1 0.878659 || Training Accuracy 0.783579 || Validation F1 0.826288 || Validation Accuracy 0.703996 || Max F1 0.854338 || LR 0.000611 || Duration 00:00:10
#
# Epoch 50 || Loss:0.031051 || Training F1 0.882303 || Training Accuracy 0.789394 || Validation F1 0.838954 || Validation Accuracy 0.722584 || Max F1 0.854338 || LR 0.000605 || Duration 00:00:10
#
# Epoch 51 || Loss:0.032932 || Training F1 0.870264 || Training Accuracy 0.770326 || Validation F1 0.828706 || Validation Accuracy 0.707513 || Max F1 0.854338 || LR 0.000599 || Duration 00:00:10
#
# Epoch 52 || Loss:0.029572 || Training F1 0.883820 || Training Accuracy 0.791826 || Validation F1 0.832260 || Validation Accuracy 0.712710 || Max F1 0.854338 || LR 0.000593 || Duration 00:00:10
#
# Epoch 53 || Loss:0.029860 || Training F1 0.882147 || Training Accuracy 0.789143 || Validation F1 0.834860 || Validation Accuracy 0.716532 || Max F1 0.854338 || LR 0.000587 || Duration 00:00:10
#
# Epoch 54 || Loss:0.028080 || Training F1 0.879495 || Training Accuracy 0.784910 || Validation F1 0.840730 || Validation Accuracy 0.725224 || Max F1 0.854338 || LR 0.000581 || Duration 00:00:10
#
# Epoch 55 || Loss:0.027422 || Training F1 0.875710 || Training Accuracy 0.778900 || Validation F1 0.817524 || Validation Accuracy 0.691367 || Max F1 0.854338 || LR 0.000575 || Duration 00:00:10
#
# Epoch 56 || Loss:0.025373 || Training F1 0.891583 || Training Accuracy 0.804375 || Validation F1 0.844323 || Validation Accuracy 0.730587 || Max F1 0.854338 || LR 0.000570 || Duration 00:00:10
#
# Epoch 57 || Loss:0.023669 || Training F1 0.854951 || Training Accuracy 0.746650 || Validation F1 0.818929 || Validation Accuracy 0.693379 || Max F1 0.854338 || LR 0.000564 || Duration 00:00:10
#
# Epoch 58 || Loss:0.051398 || Training F1 0.866714 || Training Accuracy 0.764779 || Validation F1 0.839171 || Validation Accuracy 0.722907 || Max F1 0.854338 || LR 0.000558 || Duration 00:00:10
#
# Epoch 59 || Loss:0.048963 || Training F1 0.902516 || Training Accuracy 0.822350 || Validation F1 0.851294 || Validation Accuracy 0.741090 || Max F1 0.854338 || LR 0.000553 || Duration 00:00:10
#
# Epoch 60 || Loss:0.030651 || Training F1 0.891104 || Training Accuracy 0.803595 || Validation F1 0.852632 || Validation Accuracy 0.743120 || Max F1 0.854338 || LR 0.000547 || Duration 00:00:10
#
# Epoch 61 || Loss:0.022490 || Training F1 0.909046 || Training Accuracy 0.833258 || Validation F1 0.846848 || Validation Accuracy 0.734376 || Max F1 0.854338 || LR 0.000542 || Duration 00:00:10
#
# Epoch 62 || Loss:0.020403 || Training F1 0.890869 || Training Accuracy 0.803213 || Validation F1 0.843084 || Validation Accuracy 0.728734 || Max F1 0.854338 || LR 0.000536 || Duration 00:00:10
#
# Epoch 63 || Loss:0.021662 || Training F1 0.904008 || Training Accuracy 0.824831 || Validation F1 0.849983 || Validation Accuracy 0.739105 || Max F1 0.854338 || LR 0.000531 || Duration 00:00:10
#
# Epoch 64 || Loss:0.026499 || Training F1 0.905278 || Training Accuracy 0.826948 || Validation F1 0.848856 || Validation Accuracy 0.737401 || Max F1 0.854338 || LR 0.000526 || Duration 00:00:10
#
# Epoch 65 || Loss:0.022452 || Training F1 0.905772 || Training Accuracy 0.827773 || Validation F1 0.843883 || Validation Accuracy 0.729929 || Max F1 0.854338 || LR 0.000520 || Duration 00:00:10
#
# Epoch 66 || Loss:0.021171 || Training F1 0.906765 || Training Accuracy 0.829433 || Validation F1 0.839936 || Validation Accuracy 0.724042 || Max F1 0.854338 || LR 0.000515 || Duration 00:00:10
#
# Epoch 67 || Loss:0.020626 || Training F1 0.886827 || Training Accuracy 0.796666 || Validation F1 0.829531 || Validation Accuracy 0.708717 || Max F1 0.854338 || LR 0.000510 || Duration 00:00:10
#
# Epoch 68 || Loss:0.022130 || Training F1 0.890188 || Training Accuracy 0.802107 || Validation F1 0.831781 || Validation Accuracy 0.712007 || Max F1 0.854338 || LR 0.000505 || Duration 00:00:10
#
# Epoch 69 || Loss:0.022270 || Training F1 0.888654 || Training Accuracy 0.799619 || Validation F1 0.843205 || Validation Accuracy 0.728914 || Max F1 0.854338 || LR 0.000500 || Duration 00:00:10
#
# Epoch 70 || Loss:0.019214 || Training F1 0.899358 || Training Accuracy 0.817121 || Validation F1 0.854772 || Validation Accuracy 0.746377 || Max F1 0.854772 || LR 0.000495 || Duration 00:00:10
#
# Epoch 71 || Loss:0.020277 || Training F1 0.912397 || Training Accuracy 0.838906 || Validation F1 0.820532 || Validation Accuracy 0.695680 || Max F1 0.854772 || LR 0.000490 || Duration 00:00:10
#
# Epoch 72 || Loss:0.019435 || Training F1 0.909054 || Training Accuracy 0.833272 || Validation F1 0.839083 || Validation Accuracy 0.722776 || Max F1 0.854772 || LR 0.000485 || Duration 00:00:10
#
# Epoch 73 || Loss:0.019295 || Training F1 0.891967 || Training Accuracy 0.805001 || Validation F1 0.833161 || Validation Accuracy 0.714032 || Max F1 0.854772 || LR 0.000480 || Duration 00:00:10
#
# Epoch 74 || Loss:0.022539 || Training F1 0.909162 || Training Accuracy 0.833452 || Validation F1 0.846753 || Validation Accuracy 0.734233 || Max F1 0.854772 || LR 0.000475 || Duration 00:00:10
#
# Epoch 75 || Loss:0.019886 || Training F1 0.871790 || Training Accuracy 0.772719 || Validation F1 0.813651 || Validation Accuracy 0.685845 || Max F1 0.854772 || LR 0.000471 || Duration 00:00:10
#
# Epoch 76 || Loss:0.017208 || Training F1 0.906101 || Training Accuracy 0.828322 || Validation F1 0.852515 || Validation Accuracy 0.742942 || Max F1 0.854772 || LR 0.000466 || Duration 00:00:10
#
# Epoch 77 || Loss:0.015899 || Training F1 0.906843 || Training Accuracy 0.829564 || Validation F1 0.834597 || Validation Accuracy 0.716145 || Max F1 0.854772 || LR 0.000461 || Duration 00:00:10
#
# Epoch 78 || Loss:0.017688 || Training F1 0.906161 || Training Accuracy 0.828422 || Validation F1 0.840593 || Validation Accuracy 0.725020 || Max F1 0.854772 || LR 0.000457 || Duration 00:00:10
#
# Epoch 79 || Loss:0.018513 || Training F1 0.910476 || Training Accuracy 0.835664 || Validation F1 0.844185 || Validation Accuracy 0.730380 || Max F1 0.854772 || LR 0.000452 || Duration 00:00:10
#
# Epoch 80 || Loss:0.018925 || Training F1 0.908120 || Training Accuracy 0.831704 || Validation F1 0.840671 || Validation Accuracy 0.725136 || Max F1 0.854772 || LR 0.000448 || Duration 00:00:10
#
# Epoch 81 || Loss:0.016920 || Training F1 0.895019 || Training Accuracy 0.809986 || Validation F1 0.851649 || Validation Accuracy 0.741627 || Max F1 0.854772 || LR 0.000443 || Duration 00:00:10
#
# Epoch 82 || Loss:0.016272 || Training F1 0.892512 || Training Accuracy 0.805889 || Validation F1 0.818441 || Validation Accuracy 0.692679 || Max F1 0.854772 || LR 0.000439 || Duration 00:00:10
#
# Epoch 83 || Loss:0.017182 || Training F1 0.914589 || Training Accuracy 0.842621 || Validation F1 0.847451 || Validation Accuracy 0.735284 || Max F1 0.854772 || LR 0.000434 || Duration 00:00:10
#
# Epoch 84 || Loss:0.016921 || Training F1 0.895679 || Training Accuracy 0.811068 || Validation F1 0.845794 || Validation Accuracy 0.732793 || Max F1 0.854772 || LR 0.000430 || Duration 00:00:10
#
# Epoch 85 || Loss:0.017321 || Training F1 0.901737 || Training Accuracy 0.821057 || Validation F1 0.850114 || Validation Accuracy 0.739302 || Max F1 0.854772 || LR 0.000426 || Duration 00:00:10
#
# Epoch 86 || Loss:0.016502 || Training F1 0.901051 || Training Accuracy 0.819921 || Validation F1 0.836785 || Validation Accuracy 0.719373 || Max F1 0.854772 || LR 0.000421 || Duration 00:00:10
#
# Epoch 87 || Loss:0.016137 || Training F1 0.914200 || Training Accuracy 0.841960 || Validation F1 0.855003 || Validation Accuracy 0.746730 || Max F1 0.855003 || LR 0.000417 || Duration 00:00:10
#
# Epoch 88 || Loss:0.016205 || Training F1 0.897775 || Training Accuracy 0.814511 || Validation F1 0.819659 || Validation Accuracy 0.694425 || Max F1 0.855003 || LR 0.000413 || Duration 00:00:10
#
# Epoch 89 || Loss:0.017671 || Training F1 0.909565 || Training Accuracy 0.834130 || Validation F1 0.850627 || Validation Accuracy 0.740079 || Max F1 0.855003 || LR 0.000409 || Duration 00:00:10
#
# Epoch 90 || Loss:0.016015 || Training F1 0.900130 || Training Accuracy 0.818397 || Validation F1 0.851118 || Validation Accuracy 0.740822 || Max F1 0.855003 || LR 0.000405 || Duration 00:00:10
#
# Epoch 91 || Loss:0.019039 || Training F1 0.893985 || Training Accuracy 0.808293 || Validation F1 0.850612 || Validation Accuracy 0.740057 || Max F1 0.855003 || LR 0.000401 || Duration 00:00:10
#
# Epoch 92 || Loss:0.017213 || Training F1 0.914905 || Training Accuracy 0.843157 || Validation F1 0.842559 || Validation Accuracy 0.727950 || Max F1 0.855003 || LR 0.000397 || Duration 00:00:10
#
# Epoch 93 || Loss:0.014864 || Training F1 0.906876 || Training Accuracy 0.829618 || Validation F1 0.842803 || Validation Accuracy 0.728314 || Max F1 0.855003 || LR 0.000393 || Duration 00:00:10
#
# Epoch 94 || Loss:0.013175 || Training F1 0.914508 || Training Accuracy 0.842483 || Validation F1 0.856914 || Validation Accuracy 0.749650 || Max F1 0.856914 || LR 0.000389 || Duration 00:00:10
#
# Epoch 95 || Loss:0.012471 || Training F1 0.909962 || Training Accuracy 0.834799 || Validation F1 0.857667 || Validation Accuracy 0.750803 || Max F1 0.857667 || LR 0.000385 || Duration 00:00:10
#
# Epoch 96 || Loss:0.013091 || Training F1 0.912471 || Training Accuracy 0.839031 || Validation F1 0.850917 || Validation Accuracy 0.740518 || Max F1 0.857667 || LR 0.000381 || Duration 00:00:10
#
# Epoch 97 || Loss:0.013749 || Training F1 0.899075 || Training Accuracy 0.816653 || Validation F1 0.857802 || Validation Accuracy 0.751009 || Max F1 0.857802 || LR 0.000377 || Duration 00:00:10
#
# Epoch 98 || Loss:0.014872 || Training F1 0.914509 || Training Accuracy 0.842484 || Validation F1 0.849119 || Validation Accuracy 0.737799 || Max F1 0.857802 || LR 0.000373 || Duration 00:00:10
#
# Epoch 99 || Loss:0.014101 || Training F1 0.874109 || Training Accuracy 0.776371 || Validation F1 0.826675 || Validation Accuracy 0.704557 || Max F1 0.857802 || LR 0.000370 || Duration 00:00:10

# %% [markdown]
# ## TEST RESULTS

# %%
# Utilities
to_tensor = T.ToTensor() 
toPIL = T.ToPILImage()

DIM_IMG_TEST = 608

# %%
def load_test_dataset():
    root_test_dir = "/content/drive/MyDrive/ml_epfl/ml_road_segmentation/data/test_set_images/"
    test_i = 'test_'
    n = len(os.listdir(root_test_dir))
    test_imgs = [to_tensor(Image.open(root_test_dir + test_i + str(idx_img) +'/'+ test_i + str(idx_img) + '.png')).reshape((1, 3, DIM_IMG_TEST, DIM_IMG_TEST)) for idx_img in range(1, n+1)]
    test_imgs_filtered = contrast(sharp(test_imgs))
    return test_imgs_filtered
  
test_images = load_test_dataset()

# %%
def make_predictions(model, test_images):
    model.eval()
    predicted_images = [torch.argmax(model(img.to(device)), dim = 1).cpu().float() for img in test_images]
    return predicted_images

predictions = make_predictions(model, test_images)

# %%
plt.figure(figsize=(15,15))
IMG_INDEX = 40
images = [toPIL(test_images[IMG_INDEX].reshape((3, DIM_IMG_TEST, DIM_IMG_TEST))), toPIL(predictions[IMG_INDEX])]
for i, image in enumerate(images):
    plt.subplot(1, 2, i+1)
    plt.imshow(image)

# %%
plt.figure(figsize=(15,15))
IMG_INDEX = 45
images = [toPIL(test_images[IMG_INDEX].reshape((3, DIM_IMG_TEST, DIM_IMG_TEST))), toPIL(predictions[IMG_INDEX])]
for i, image in enumerate(images):
    plt.subplot(1, 2, i+1)
    plt.imshow(image)

# %%
plt.figure(figsize=(15,15))
IMG_INDEX = 45
images = [toPIL(test_images[IMG_INDEX].reshape((3, DIM_IMG_TEST, DIM_IMG_TEST))), toPIL(predictions[IMG_INDEX])]
for i, image in enumerate(images):
    plt.subplot(1, 2, i+1)
    plt.imshow(image)

# %% [markdown]
# ## JUST TO TRY ROTATION

# %%
# Just for testing
root_dir = "/content/drive/MyDrive/ml_epfl/ml_road_segmentation/data/training/images/"
files = os.listdir(root_dir)
to_tensor = T.ToTensor()
imgs = [to_tensor(Image.open(root_dir + files[i])) for i in range(1)]

ANGLE_ROTATION = 15
NB_ROT = 3
rot_imgs = imgs + [torch.from_numpy(sc.rotate(imgs[i], ANGLE_ROTATION*(idx_rot+1), axes =(1,2), reshape=False, mode="mirror")) for idx_rot in range(NB_ROT) for i in range(len(imgs)) ]

plt.figure(figsize=(25,25))
for i, image in enumerate(rot_imgs):
    plt.subplot(1, 4, i+1)
    plt.imshow(toPIL(image))
