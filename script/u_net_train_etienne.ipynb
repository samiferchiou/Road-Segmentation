# %% [markdown]
# ## MOUNT Google Drive

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !lscpu |grep 'Model name'
# !lscpu |grep 'Core(s) per socket:'
# !free -h
# !lscpu |grep 'Thread(s) per core'
# Out:
# Model name:          Intel(R) Xeon(R) CPU @ 2.30GHz
# Core(s) per socket:  4
#               total        used        free      shared  buff/cache   available
# Mem:            51G        6.3G         33G         16M         11G         47G
# Swap:            0B          0B          0B
# Thread(s) per core:  2

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Mon Dec 20 22:29:26 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   57C    P0    37W / 250W |   3611MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ## IMPORTS

# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torch.optim.lr_scheduler import ExponentialLR
import numpy as np
import random
import os, sys, time
from PIL import Image
import torchvision.transforms as T
import scipy.ndimage as sc
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
from PIL import ImageFilter

sys.path.append('/content/drive/MyDrive/ml_epfl/ml_road_segmentation/script/')
#from helper_functions import *

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %% [markdown]
# ## CONSTANTS

# %%
CHECKPOINT_PATH ="/content/drive/MyDrive/ml_epfl/ml_road_segmentation/checkpoint/current_checkpoint_filters.pt"
BEST_MODEL_PATH ="/content/drive/MyDrive/ml_epfl/ml_road_segmentation/checkpoint/best_model_mirror_filters.pt"
NBR_EPOCHS = 100
BATCH_SIZE = 1
LEARNING_RATE = 1e-3
WEIGHT_DECAY = 1e-6
GAMMA = 1
K_FOLD = 4
VALIDATION_SET_IDX = 0
BATCH_SIZE_VAL = 5
SEED = 0
FILTER = ImageFilter.FIND_EDGES # ImageFilter.CONTOUR, ImageFilter.DETAIL

# %% [markdown]
# ## AUXILIARY FUNCTIONS

# %%
def format_time(seconds):
    return time.strftime("%H:%M:%S", time.gmtime(seconds))

# %%
def save_ckp(state, is_best, checkpoint_path, best_model_path):
    """
    state:            checkpoint we want to save
    is_best:          boolean to indicates if it is the best checkpoint
    checkpoint_path:  path to save checkpoint
    best_model_path:  path to save best model
    """
    torch.save(state, checkpoint_path)
    # if it is a best model, save the model's weights
    if is_best:
        torch.save(model.state_dict(), best_model_path)

# %%
def load_ckp(checkpoint_fpath, model, optimizer):
    """
    checkpoint_path: path to save checkpoint
    model:           model that we want to load checkpoint parameters into       
    optimizer:       optimizer we defined in previous training
    
    Return model, optimizer, scheduler, epoch value, f1 score
    """
    checkpoint = torch.load(checkpoint_fpath)
    # initialize state_dict from checkpoint to model
    model.load_state_dict(checkpoint['state_dict'])
    # initialize optimizer from checkpoint to optimizer
    optimizer.load_state_dict(checkpoint['optimizer'])
    # Get epoch number, f1_max, scheduler
    epoch = checkpoint['epoch']
    f1_max = checkpoint['f1_max']
    scheduler = checkpoint['scheduler']
    f1_validation = checkpoint['f1_validation']
    acc_validation = checkpoint['acc_validation']
    f1_training = checkpoint['scheduler']
    acc_training = checkpoint['acc_training']


    return model, optimizer, scheduler, epoch, f1_max, f1_validation, acc_validation, f1_training, acc_training

# %%
# FUNCTIONS FOR DATASET AUGMENTATION

#Constants
DIM_IMG = 400
DIM_IMG_CROP=DIM_IMG//2
NB_ROT = 20
ANGLE_ROTATION = 9
    
# Old Rotation
def rotation_old(imgs):
    rot_imgs = [T.functional.rotate(imgs[i], ANGLE_ROTATION*(idx_rot), expand=False)
                for idx_rot in range(NB_ROT)
                for i in range(len(imgs))
                ]
    return rot_imgs

# Rotation with mirroring
def rotation(imgs):
    rot_imgs = [torch.from_numpy(sc.rotate(imgs[i], ANGLE_ROTATION*(idx_rot+1), axes =(1,2), reshape=False, mode ='mirror'))
                for idx_rot in range(NB_ROT)
                for i in range(len(imgs))
               ]
    return rot_imgs

#Crop and resize
def crop(imgs):
    cropped_imgs = [T.Resize(size=DIM_IMG)(T.FiveCrop(size=DIM_IMG_CROP)(imgs[i])[tuple_i])
                    for tuple_i in range(5)
                    for i in range(len(imgs))
                   ]
    return cropped_imgs

def compose_all_functions_for_data(imgs):
    #c = imgs + crop(imgs)
    #r = c + rotation(c)
    r = imgs + rotation(imgs)
    return r

def load_train_dataset():
    root_dir = "/content/drive/MyDrive/ml_epfl/ml_road_segmentation/data/training/"
    image_dir = root_dir + "images/"
    gt_dir = root_dir + "groundtruth/"
    files = os.listdir(image_dir)
    n = len(files)

    to_tensor = T.ToTensor()
    imgs = [to_tensor(Image.open(image_dir + files[i])) for i in range(n)]
    gt_imgs = [to_tensor(Image.open(gt_dir + files[i])) for i in range(n)]
    return (imgs, gt_imgs)

# %% [markdown]
# ## UNET MODEL

# %%
def double_conv(nbr_channels_in, nbr_channels_out):
    return nn.Sequential(
      nn.Conv2d(nbr_channels_in, nbr_channels_out, (3,3), padding=(1, 1)),
      nn.BatchNorm2d(nbr_channels_out),
      nn.ReLU(),
      nn.Conv2d(nbr_channels_out, nbr_channels_out, (3,3), padding=(1, 1)),
      nn.ReLU(),
      nn.BatchNorm2d(nbr_channels_out),
)


def one_step_up(x, x_d_i, pre_up_i, up_i):
    return up_i(torch.cat((pre_up_i(x), x_d_i), dim=1))


class u_net(nn.Module):
    def __init__(self):
        super(u_net, self).__init__()

        self.down_pooling = nn.MaxPool2d(2, 2)

        # Convolution Downwards
        self.down_1 = double_conv(6, 64) 
        self.down_2 = double_conv(64, 128)
        self.down_3 = double_conv(128, 256)
        self.down_4 = double_conv(256, 512)
        self.middle =  double_conv(512, 1024)
        
        # Upconvolution
        self.pre_up_1 = nn.ConvTranspose2d(1024, 512, (2, 2), (2, 2))
        self.up_1 = double_conv(512 + 512, 512)
                
        self.pre_up_2 = nn.ConvTranspose2d(512, 256, (2, 2), (2, 2))
        self.up_2 = double_conv(256 + 256, 256)
          
        self.pre_up_3 = nn.ConvTranspose2d(256, 128, (2, 2), (2, 2))
        self.up_3 = double_conv(128 + 128, 128)

        self.pre_up_4 = nn.ConvTranspose2d(128, 64, (2, 2), (2, 2))
        self.up_4 = double_conv(64 + 64, 64)

        self.final_convolution = nn.Conv2d(64, 2, (1,1))
        

    def forward(self, x):
        x_d_1 = self.down_1(x)
        x_d_2 = self.down_2(self.down_pooling(x_d_1))
        x_d_3 = self.down_3(self.down_pooling(x_d_2))
        x_d_4 = self.down_4(self.down_pooling(x_d_3))

        x = self.middle(self.down_pooling(x_d_4))

        x = one_step_up(x, x_d_4, self.pre_up_1, self.up_1)
        x = one_step_up(x, x_d_3, self.pre_up_2, self.up_2)
        x = one_step_up(x, x_d_2, self.pre_up_3, self.up_3)
        x = one_step_up(x, x_d_1, self.pre_up_4, self.up_4)
        
        return self.final_convolution(x)

# %% [markdown]
# ## DATASET LOADING

# %%
def append_filter(filter_to_apply, images):
    to_tensor = T.ToTensor() 
    toPIL = T.ToPILImage()
    
    concatenated_images = []

    for img in images:
      filtered_img = toPIL(img).filter(filter_to_apply)
      tensored_img = to_tensor(filtered_img)
      #stacked_img = torch.stack((img, tensored_img), dim=1)
      stacked_img = torch.cat((img, tensored_img), dim=0)
      concatenated_images.append(stacked_img)
    
    return concatenated_images

# %%
class imagesDataset(Dataset): 
    def __init__(self, K_fold, validation_set_idx, batch_size_val, seed, filter_img):
        X, Y = load_train_dataset()

        #tresholding ground_truth values
        Y = [(y > 0.5).long() for y in Y]
        shape_y = Y[0].shape
        
        #shuffling
        random.seed(seed)
        idx_list = list(range(len(X)))
        random.shuffle(idx_list)
        random.seed()
        X = [X[idx] for idx in idx_list]
        Y = [Y[idx] for idx in idx_list]
        
        #K_fold separation
        fold_size = len(X) // K_fold
        start_validation_idx = validation_set_idx * fold_size
        end_validation_idx = start_validation_idx + fold_size
        self.X_train = X[slice(0, start_validation_idx)] + X[slice(end_validation_idx, None)]
        self.Y_train = Y[slice(0, start_validation_idx)] + Y[slice(end_validation_idx, None)]
        self.X_validation = X[slice(start_validation_idx, end_validation_idx)]
        self.Y_validation = Y[slice(start_validation_idx, end_validation_idx)]

        #data augmentation
        self.X_train = compose_all_functions_for_data(self.X_train)
        self.Y_train = compose_all_functions_for_data(self.Y_train)
        self.X_validation = compose_all_functions_for_data(self.X_validation)
        self.Y_validation = compose_all_functions_for_data(self.Y_validation)
        self.n_samples = len(self.X_train)

         #apply filter
        self.X_train = append_filter(filter_img, self.X_train)
        self.X_validation = append_filter(filter_img, self.X_validation)

        #2nd shuffling
        random.seed(seed)
        idx_list = list(range(len(self.X_train)))
        random.shuffle(idx_list)
        random.seed()
        self.X_train = [self.X_train[idx] for idx in idx_list]
        self.Y_train = [self.Y_train[idx] for idx in idx_list]
        
        #casting into tensors
        self.X_train = torch.stack(self.X_train)
        self.X_validation = torch.stack(self.X_validation)
        self.Y_train = torch.reshape(torch.stack(self.Y_train) , (-1, shape_y[1], shape_y[2]))
        self.Y_validation = torch.reshape(torch.stack(self.Y_validation) , (-1, shape_y[1], shape_y[2]))

        #creating dataloader for validation data
        class dataset_validation(Dataset):
            def __init__(s,x,y):
                s.x = x
                s.y = y
                s.size = len(s.x)
            def __getitem__(s, index):
                return s.x[index], s.y[index]
            def __len__(s):
                return s.size
               
        self.validation_data_loader = torch.utils.data.DataLoader(
            dataset_validation(self.X_validation, self.Y_validation),
            batch_size = batch_size_val, shuffle = False)
        
        
    def __getitem__(self, index):
        return self.X_train[index], self.Y_train[index]

    def __len__(self):
        return self.n_samples
    
    def get_validation_dataloader(self):
        return self.validation_data_loader


dataset = imagesDataset(K_FOLD, VALIDATION_SET_IDX, BATCH_SIZE_VAL, SEED, FILTER)
train_loader = torch.utils.data.DataLoader(dataset, batch_size = BATCH_SIZE, shuffle = True)
validation_dataloader = dataset.get_validation_dataloader()
print(len(dataset))
# Out:
# 1575

# %% [markdown]
# ## TRAINING

# %%
def compute_scores(loader):
    #computing F1 score on validation data
    tp, fp, fn, tn = 0, 0, 0, 0
    for (data, target) in loader:
        data, target = data.to(device), target.to(device)
        with torch.no_grad():
            output = model(data)
        prediction = torch.argmax(output, dim = 1)
        confusions = prediction / target
        tp += torch.sum(confusions == 1).item()
        fp += torch.sum(confusions == float('inf')).item()
        fn += torch.sum(confusions == 0).item()
        tn += torch.sum(confusions == float("nan")).item()
    f1_score = 2 * tp / (2 * tp + fp + fn)
    accuracy = (tp + tn) / (tp + tn + fp+ fn)
    return f1_score, accuracy

# %%
def train(n_epochs, data_loader, model, optimizer, scheduler, criterion, device, checkpoint_path, best_model_path, f1_init):
    train_loader = data_loader
    validation_loader = train_loader.dataset.get_validation_dataloader()
    f1_max = f1_init
    
    save_f1_validation = []
    save_acc_validation = []
    save_f1_training = []
    save_acc_training = []

    for epoch in range(n_epochs):
        start_time_epoch = time.time()
        loss_list = []
        
        # Train the model for one epoch
        model.train()
        for (data, target) in train_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            loss = criterion(output, target)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            loss_list.append(loss.item())
        loss_epoch = np.mean(loss_list)

        model.eval()
        #computing scores on validation data
        f1_score_val, accuracy_score_val = compute_scores(validation_loader)
        save_f1_validation.append(f1_score_val)
        save_acc_validation.append(accuracy_score_val)

        #computing scores on training data
        f1_score_train, accuracy_score_train = compute_scores(train_loader)
        save_f1_training.append(f1_score_train)
        save_acc_training.append(accuracy_score_train)

        end_time_epoch = time.time()

        # Prepare saving of the model
        checkpoint = {
            'epoch': epoch,
            'f1_max': f1_max,
            'state_dict': model.state_dict(),
            'optimizer': optimizer.state_dict(),
            'scheduler': scheduler,
            'f1_validation' : save_f1_validation,
            'acc_validation' : save_acc_validation,
            'f1_training' : save_f1_training,
            'acc_training' : save_acc_training,
        }

        if f1_score_val > f1_max:
            save_ckp(checkpoint, True, checkpoint_path, best_model_path)
            f1_max = f1_score_val
        
        save_ckp(checkpoint, False, checkpoint_path, best_model_path)

        print(f"Epoch {epoch} || Loss:{loss_epoch:.6f} || Training F1 {f1_score_train:.6f} || Training Accuracy {accuracy_score_train:.6f} || Validation F1 {f1_score_val:.6f} || Validation Accuracy {accuracy_score_val:.6f} || Max F1 {f1_max:.6f} || LR {scheduler.get_last_lr()[0]:.6f} || Duration {format_time(end_time_epoch-start_time_epoch)}"+"\n")  
        scheduler.step()

# %%
LOAD_BEST_MODEL = False
LOAD_LAST_CHECKPOINT = not LOAD_BEST_MODEL
COLD_START = True

# Declare UNET model, otimizer, adaptative learning rate and loss function
model =  u_net().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE, weight_decay=WEIGHT_DECAY)
scheduler = ExponentialLR(optimizer, GAMMA)
criterion = nn.CrossEntropyLoss()
f1_max = 0

if not COLD_START:
    if LOAD_LAST_CHECKPOINT and not LOAD_BEST_MODEL:
        model, optimizer, scheduler, epoch, f1_max, _ , _, _, _  = load_ckp(CHECKPOINT_PATH, model, optimizer)
    
    if not LOAD_LAST_CHECKPOINT and LOAD_BEST_MODEL:
        model.load_state_dict(torch.load(BEST_MODEL_PATH))

# %%
train(NBR_EPOCHS, train_loader, model, optimizer, scheduler, criterion, device, CHECKPOINT_PATH, BEST_MODEL_PATH, f1_max)
# Out:
# Epoch 0 || Loss:0.350017 || Training F1 0.639255 || Training Accuracy 0.469784 || Validation F1 0.618587 || Validation Accuracy 0.447793 || Max F1 0.618587 || LR 0.001000 || Duration 00:03:42
#
# Epoch 1 || Loss:0.232007 || Training F1 0.754078 || Training Accuracy 0.605237 || Validation F1 0.750316 || Validation Accuracy 0.600405 || Max F1 0.750316 || LR 0.001000 || Duration 00:03:42
#
# Epoch 2 || Loss:0.183016 || Training F1 0.784539 || Training Accuracy 0.645467 || Validation F1 0.779209 || Validation Accuracy 0.638282 || Max F1 0.779209 || LR 0.001000 || Duration 00:03:42
#
# Epoch 3 || Loss:0.149896 || Training F1 0.813277 || Training Accuracy 0.685313 || Validation F1 0.822535 || Validation Accuracy 0.698565 || Max F1 0.822535 || LR 0.001000 || Duration 00:03:42
#
# Epoch 4 || Loss:0.131405 || Training F1 0.834180 || Training Accuracy 0.715530 || Validation F1 0.837543 || Validation Accuracy 0.720494 || Max F1 0.837543 || LR 0.001000 || Duration 00:03:42
#
# Epoch 5 || Loss:0.113416 || Training F1 0.828011 || Training Accuracy 0.706501 || Validation F1 0.844311 || Validation Accuracy 0.730570 || Max F1 0.844311 || LR 0.001000 || Duration 00:03:42
#
# Epoch 6 || Loss:0.100991 || Training F1 0.831283 || Training Accuracy 0.711278 || Validation F1 0.837356 || Validation Accuracy 0.720217 || Max F1 0.844311 || LR 0.001000 || Duration 00:03:42
#
# Epoch 7 || Loss:0.087834 || Training F1 0.835788 || Training Accuracy 0.717901 || Validation F1 0.854378 || Validation Accuracy 0.745776 || Max F1 0.854378 || LR 0.001000 || Duration 00:03:42
#
# Epoch 8 || Loss:0.086839 || Training F1 0.851043 || Training Accuracy 0.740709 || Validation F1 0.845243 || Validation Accuracy 0.731966 || Max F1 0.854378 || LR 0.001000 || Duration 00:03:42
#
# Epoch 9 || Loss:0.078416 || Training F1 0.851450 || Training Accuracy 0.741326 || Validation F1 0.846089 || Validation Accuracy 0.733235 || Max F1 0.854378 || LR 0.001000 || Duration 00:03:42
#
# Epoch 10 || Loss:0.068945 || Training F1 0.828239 || Training Accuracy 0.706833 || Validation F1 0.830893 || Validation Accuracy 0.710707 || Max F1 0.854378 || LR 0.001000 || Duration 00:03:42
#
# Epoch 11 || Loss:0.062594 || Training F1 0.873507 || Training Accuracy 0.775422 || Validation F1 0.852627 || Validation Accuracy 0.743112 || Max F1 0.854378 || LR 0.001000 || Duration 00:03:42
#
# Epoch 12 || Loss:0.057848 || Training F1 0.863325 || Training Accuracy 0.759517 || Validation F1 0.858258 || Validation Accuracy 0.751710 || Max F1 0.858258 || LR 0.001000 || Duration 00:03:42
#
# Epoch 13 || Loss:0.056532 || Training F1 0.867298 || Training Accuracy 0.765690 || Validation F1 0.857332 || Validation Accuracy 0.750289 || Max F1 0.858258 || LR 0.001000 || Duration 00:03:42
#
# Epoch 14 || Loss:0.070509 || Training F1 0.864167 || Training Accuracy 0.760823 || Validation F1 0.854998 || Validation Accuracy 0.746722 || Max F1 0.858258 || LR 0.001000 || Duration 00:03:42
#
# Epoch 15 || Loss:0.049270 || Training F1 0.862791 || Training Accuracy 0.758692 || Validation F1 0.848612 || Validation Accuracy 0.737033 || Max F1 0.858258 || LR 0.001000 || Duration 00:03:42
#
# Epoch 16 || Loss:0.045919 || Training F1 0.874914 || Training Accuracy 0.777642 || Validation F1 0.855753 || Validation Accuracy 0.747875 || Max F1 0.858258 || LR 0.001000 || Duration 00:03:42
#
# Epoch 17 || Loss:0.045348 || Training F1 0.739921 || Training Accuracy 0.587202 || Validation F1 0.764788 || Validation Accuracy 0.619156 || Max F1 0.858258 || LR 0.001000 || Duration 00:03:42
#
# Epoch 18 || Loss:0.059294 || Training F1 0.883324 || Training Accuracy 0.791030 || Validation F1 0.855856 || Validation Accuracy 0.748032 || Max F1 0.858258 || LR 0.001000 || Duration 00:03:42
#
# Epoch 19 || Loss:0.038352 || Training F1 0.877389 || Training Accuracy 0.781561 || Validation F1 0.865716 || Validation Accuracy 0.763227 || Max F1 0.865716 || LR 0.001000 || Duration 00:03:42
#
# Epoch 20 || Loss:0.040142 || Training F1 0.878842 || Training Accuracy 0.783870 || Validation F1 0.866696 || Validation Accuracy 0.764752 || Max F1 0.866696 || LR 0.001000 || Duration 00:03:42
#
# Epoch 21 || Loss:0.037957 || Training F1 0.870863 || Training Accuracy 0.771264 || Validation F1 0.851250 || Validation Accuracy 0.741023 || Max F1 0.866696 || LR 0.001000 || Duration 00:03:42
#
# Epoch 22 || Loss:0.037029 || Training F1 0.887472 || Training Accuracy 0.797708 || Validation F1 0.860144 || Validation Accuracy 0.754607 || Max F1 0.866696 || LR 0.001000 || Duration 00:03:42
#
# Epoch 23 || Loss:0.036697 || Training F1 0.859014 || Training Accuracy 0.752869 || Validation F1 0.829854 || Validation Accuracy 0.709188 || Max F1 0.866696 || LR 0.001000 || Duration 00:03:42
#
# Epoch 24 || Loss:0.034005 || Training F1 0.898724 || Training Accuracy 0.816076 || Validation F1 0.860618 || Validation Accuracy 0.755337 || Max F1 0.866696 || LR 0.001000 || Duration 00:03:42
#
# Epoch 25 || Loss:0.063129 || Training F1 0.892474 || Training Accuracy 0.805827 || Validation F1 0.859416 || Validation Accuracy 0.753487 || Max F1 0.866696 || LR 0.001000 || Duration 00:03:42
#
# Epoch 26 || Loss:0.029869 || Training F1 0.886309 || Training Accuracy 0.795830 || Validation F1 0.865587 || Validation Accuracy 0.763026 || Max F1 0.866696 || LR 0.001000 || Duration 00:03:42
#
# Epoch 27 || Loss:0.032212 || Training F1 0.872026 || Training Accuracy 0.773090 || Validation F1 0.844532 || Validation Accuracy 0.730900 || Max F1 0.866696 || LR 0.001000 || Duration 00:03:42
#
# Epoch 28 || Loss:0.032310 || Training F1 0.885685 || Training Accuracy 0.794825 || Validation F1 0.850563 || Validation Accuracy 0.739982 || Max F1 0.866696 || LR 0.001000 || Duration 00:03:42
#
# Epoch 29 || Loss:0.031505 || Training F1 0.886794 || Training Accuracy 0.796612 || Validation F1 0.857407 || Validation Accuracy 0.750404 || Max F1 0.866696 || LR 0.001000 || Duration 00:03:42
#
# Epoch 30 || Loss:0.031186 || Training F1 0.890535 || Training Accuracy 0.802670 || Validation F1 0.859882 || Validation Accuracy 0.754205 || Max F1 0.866696 || LR 0.001000 || Duration 00:03:42
#
# Epoch 31 || Loss:0.030922 || Training F1 0.879873 || Training Accuracy 0.785511 || Validation F1 0.847999 || Validation Accuracy 0.736109 || Max F1 0.866696 || LR 0.001000 || Duration 00:03:42
#
# Epoch 32 || Loss:0.037991 || Training F1 0.838186 || Training Accuracy 0.721445 || Validation F1 0.842396 || Validation Accuracy 0.727706 || Max F1 0.866696 || LR 0.001000 || Duration 00:03:42
#
# Epoch 33 || Loss:0.036685 || Training F1 0.902348 || Training Accuracy 0.822071 || Validation F1 0.871335 || Validation Accuracy 0.772004 || Max F1 0.871335 || LR 0.001000 || Duration 00:03:42
#
# Epoch 34 || Loss:0.025800 || Training F1 0.902645 || Training Accuracy 0.822565 || Validation F1 0.867361 || Validation Accuracy 0.765787 || Max F1 0.871335 || LR 0.001000 || Duration 00:03:42
#
# Epoch 35 || Loss:0.028881 || Training F1 0.893826 || Training Accuracy 0.808034 || Validation F1 0.861660 || Validation Accuracy 0.756944 || Max F1 0.871335 || LR 0.001000 || Duration 00:03:42
#
# Epoch 36 || Loss:0.039311 || Training F1 0.898688 || Training Accuracy 0.816016 || Validation F1 0.867821 || Validation Accuracy 0.766505 || Max F1 0.871335 || LR 0.001000 || Duration 00:03:42
#
# Epoch 37 || Loss:0.025330 || Training F1 0.899321 || Training Accuracy 0.817059 || Validation F1 0.859913 || Validation Accuracy 0.754252 || Max F1 0.871335 || LR 0.001000 || Duration 00:03:42
#
# Epoch 38 || Loss:0.031311 || Training F1 0.893145 || Training Accuracy 0.806921 || Validation F1 0.864124 || Validation Accuracy 0.760756 || Max F1 0.871335 || LR 0.001000 || Duration 00:03:42
#
# Epoch 39 || Loss:0.026651 || Training F1 0.894236 || Training Accuracy 0.808705 || Validation F1 0.862942 || Validation Accuracy 0.758926 || Max F1 0.871335 || LR 0.001000 || Duration 00:03:42
#
# Epoch 40 || Loss:0.037190 || Training F1 0.899915 || Training Accuracy 0.818041 || Validation F1 0.864252 || Validation Accuracy 0.760954 || Max F1 0.871335 || LR 0.001000 || Duration 00:03:42
#
# Epoch 41 || Loss:0.024720 || Training F1 0.896731 || Training Accuracy 0.812795 || Validation F1 0.861653 || Validation Accuracy 0.756934 || Max F1 0.871335 || LR 0.001000 || Duration 00:03:42
#
# Epoch 42 || Loss:0.025191 || Training F1 0.883717 || Training Accuracy 0.791660 || Validation F1 0.867370 || Validation Accuracy 0.765802 || Max F1 0.871335 || LR 0.001000 || Duration 00:03:42
#
# Epoch 43 || Loss:0.029630 || Training F1 0.899880 || Training Accuracy 0.817983 || Validation F1 0.863400 || Validation Accuracy 0.759635 || Max F1 0.871335 || LR 0.001000 || Duration 00:03:42
#
# Epoch 44 || Loss:0.025569 || Training F1 0.891779 || Training Accuracy 0.804693 || Validation F1 0.866954 || Validation Accuracy 0.765153 || Max F1 0.871335 || LR 0.001000 || Duration 00:03:42
#
# Epoch 45 || Loss:0.034315 || Training F1 0.865416 || Training Accuracy 0.762761 || Validation F1 0.847825 || Validation Accuracy 0.735847 || Max F1 0.871335 || LR 0.001000 || Duration 00:03:42
#
# Epoch 46 || Loss:0.026785 || Training F1 0.899725 || Training Accuracy 0.817727 || Validation F1 0.872146 || Validation Accuracy 0.773279 || Max F1 0.872146 || LR 0.001000 || Duration 00:03:42
#
# Epoch 47 || Loss:0.023135 || Training F1 0.897299 || Training Accuracy 0.813728 || Validation F1 0.873472 || Validation Accuracy 0.775367 || Max F1 0.873472 || LR 0.001000 || Duration 00:03:42
#
# Epoch 48 || Loss:0.025625 || Training F1 0.893143 || Training Accuracy 0.806919 || Validation F1 0.865744 || Validation Accuracy 0.763270 || Max F1 0.873472 || LR 0.001000 || Duration 00:03:42
#
# Epoch 49 || Loss:0.027123 || Training F1 0.901277 || Training Accuracy 0.820295 || Validation F1 0.871209 || Validation Accuracy 0.771808 || Max F1 0.873472 || LR 0.001000 || Duration 00:03:42
#
# Epoch 50 || Loss:0.027303 || Training F1 0.898239 || Training Accuracy 0.815275 || Validation F1 0.863566 || Validation Accuracy 0.759891 || Max F1 0.873472 || LR 0.001000 || Duration 00:03:42
#
# Epoch 51 || Loss:0.023433 || Training F1 0.886950 || Training Accuracy 0.796864 || Validation F1 0.861199 || Validation Accuracy 0.756233 || Max F1 0.873472 || LR 0.001000 || Duration 00:03:41
#
# Epoch 52 || Loss:0.024861 || Training F1 0.877853 || Training Accuracy 0.782298 || Validation F1 0.861014 || Validation Accuracy 0.755948 || Max F1 0.873472 || LR 0.001000 || Duration 00:03:42
#
# Epoch 53 || Loss:0.024997 || Training F1 0.890391 || Training Accuracy 0.802436 || Validation F1 0.866466 || Validation Accuracy 0.764394 || Max F1 0.873472 || LR 0.001000 || Duration 00:03:42
#
# Epoch 54 || Loss:0.024526 || Training F1 0.898688 || Training Accuracy 0.816016 || Validation F1 0.866468 || Validation Accuracy 0.764397 || Max F1 0.873472 || LR 0.001000 || Duration 00:03:42
#
# Epoch 55 || Loss:0.033972 || Training F1 0.903788 || Training Accuracy 0.824465 || Validation F1 0.874134 || Validation Accuracy 0.776410 || Max F1 0.874134 || LR 0.001000 || Duration 00:03:42
#
# Epoch 56 || Loss:0.021482 || Training F1 0.879262 || Training Accuracy 0.784539 || Validation F1 0.849669 || Validation Accuracy 0.738630 || Max F1 0.874134 || LR 0.001000 || Duration 00:03:42
#
# Epoch 57 || Loss:0.022823 || Training F1 0.902690 || Training Accuracy 0.822638 || Validation F1 0.870971 || Validation Accuracy 0.771434 || Max F1 0.874134 || LR 0.001000 || Duration 00:03:42
#
# Epoch 58 || Loss:0.028859 || Training F1 0.901689 || Training Accuracy 0.820978 || Validation F1 0.868670 || Validation Accuracy 0.767830 || Max F1 0.874134 || LR 0.001000 || Duration 00:03:42
#
# Epoch 59 || Loss:0.022079 || Training F1 0.895955 || Training Accuracy 0.811520 || Validation F1 0.866401 || Validation Accuracy 0.764292 || Max F1 0.874134 || LR 0.001000 || Duration 00:03:42
#
# Epoch 60 || Loss:0.024520 || Training F1 0.879248 || Training Accuracy 0.784516 || Validation F1 0.850786 || Validation Accuracy 0.740320 || Max F1 0.874134 || LR 0.001000 || Duration 00:03:42
#
# Epoch 61 || Loss:0.023768 || Training F1 0.898354 || Training Accuracy 0.815465 || Validation F1 0.862915 || Validation Accuracy 0.758883 || Max F1 0.874134 || LR 0.001000 || Duration 00:03:42
#
# Epoch 62 || Loss:0.023840 || Training F1 0.887455 || Training Accuracy 0.797680 || Validation F1 0.850437 || Validation Accuracy 0.739791 || Max F1 0.874134 || LR 0.001000 || Duration 00:03:42
#
# Epoch 63 || Loss:0.029830 || Training F1 0.905031 || Training Accuracy 0.826535 || Validation F1 0.868277 || Validation Accuracy 0.767216 || Max F1 0.874134 || LR 0.001000 || Duration 00:03:42
#
# Epoch 64 || Loss:0.020402 || Training F1 0.903571 || Training Accuracy 0.824104 || Validation F1 0.862357 || Validation Accuracy 0.758020 || Max F1 0.874134 || LR 0.001000 || Duration 00:03:42
#
# Epoch 65 || Loss:0.026315 || Training F1 0.778365 || Training Accuracy 0.637150 || Validation F1 0.786659 || Validation Accuracy 0.648342 || Max F1 0.874134 || LR 0.001000 || Duration 00:03:42
#
# Epoch 66 || Loss:0.023510 || Training F1 0.885993 || Training Accuracy 0.795320 || Validation F1 0.850796 || Validation Accuracy 0.740335 || Max F1 0.874134 || LR 0.001000 || Duration 00:03:42
#
# Epoch 67 || Loss:0.033857 || Training F1 0.904866 || Training Accuracy 0.826261 || Validation F1 0.869708 || Validation Accuracy 0.769454 || Max F1 0.874134 || LR 0.001000 || Duration 00:03:42
#
# Epoch 68 || Loss:0.020139 || Training F1 0.906628 || Training Accuracy 0.829203 || Validation F1 0.872600 || Validation Accuracy 0.773993 || Max F1 0.874134 || LR 0.001000 || Duration 00:03:42
#
# Epoch 69 || Loss:0.021016 || Training F1 0.900850 || Training Accuracy 0.819587 || Validation F1 0.860196 || Validation Accuracy 0.754688 || Max F1 0.874134 || LR 0.001000 || Duration 00:03:42
#
# Epoch 70 || Loss:0.023639 || Training F1 0.907004 || Training Accuracy 0.829834 || Validation F1 0.863101 || Validation Accuracy 0.759172 || Max F1 0.874134 || LR 0.001000 || Duration 00:03:42
#
# Epoch 71 || Loss:0.023079 || Training F1 0.904816 || Training Accuracy 0.826178 || Validation F1 0.870206 || Validation Accuracy 0.770235 || Max F1 0.874134 || LR 0.001000 || Duration 00:03:42
#
# Epoch 72 || Loss:0.024592 || Training F1 0.874829 || Training Accuracy 0.777507 || Validation F1 0.840381 || Validation Accuracy 0.724704 || Max F1 0.874134 || LR 0.001000 || Duration 00:03:42
#
# Epoch 73 || Loss:0.020946 || Training F1 0.901561 || Training Accuracy 0.820766 || Validation F1 0.859250 || Validation Accuracy 0.753232 || Max F1 0.874134 || LR 0.001000 || Duration 00:03:42
#
# Epoch 74 || Loss:0.029074 || Training F1 0.910200 || Training Accuracy 0.835199 || Validation F1 0.870042 || Validation Accuracy 0.769977 || Max F1 0.874134 || LR 0.001000 || Duration 00:03:42
#
# Epoch 75 || Loss:0.019997 || Training F1 0.890647 || Training Accuracy 0.802853 || Validation F1 0.862103 || Validation Accuracy 0.757629 || Max F1 0.874134 || LR 0.001000 || Duration 00:03:42
#
# Epoch 76 || Loss:0.021641 || Training F1 0.894227 || Training Accuracy 0.808689 || Validation F1 0.860982 || Validation Accuracy 0.755899 || Max F1 0.874134 || LR 0.001000 || Duration 00:03:42
#
# Epoch 77 || Loss:0.034507 || Training F1 0.897388 || Training Accuracy 0.813876 || Validation F1 0.861542 || Validation Accuracy 0.756762 || Max F1 0.874134 || LR 0.001000 || Duration 00:03:42
#
# Epoch 78 || Loss:0.019828 || Training F1 0.901348 || Training Accuracy 0.820413 || Validation F1 0.872936 || Validation Accuracy 0.774521 || Max F1 0.874134 || LR 0.001000 || Duration 00:03:42
#
# Epoch 79 || Loss:0.020131 || Training F1 0.892590 || Training Accuracy 0.806016 || Validation F1 0.867292 || Validation Accuracy 0.765680 || Max F1 0.874134 || LR 0.001000 || Duration 00:03:42
#
# Epoch 80 || Loss:0.022355 || Training F1 0.899325 || Training Accuracy 0.817067 || Validation F1 0.862866 || Validation Accuracy 0.758807 || Max F1 0.874134 || LR 0.001000 || Duration 00:03:42
#
# Epoch 81 || Loss:0.026974 || Training F1 0.894534 || Training Accuracy 0.809193 || Validation F1 0.856706 || Validation Accuracy 0.749331 || Max F1 0.874134 || LR 0.001000 || Duration 00:03:42
#
# Epoch 82 || Loss:0.022770 || Training F1 0.899498 || Training Accuracy 0.817352 || Validation F1 0.860652 || Validation Accuracy 0.755389 || Max F1 0.874134 || LR 0.001000 || Duration 00:03:42
#
# Epoch 83 || Loss:0.020240 || Training F1 0.903330 || Training Accuracy 0.823703 || Validation F1 0.871411 || Validation Accuracy 0.772125 || Max F1 0.874134 || LR 0.001000 || Duration 00:03:42
#
# Epoch 84 || Loss:0.024391 || Training F1 0.897202 || Training Accuracy 0.813568 || Validation F1 0.860770 || Validation Accuracy 0.755571 || Max F1 0.874134 || LR 0.001000 || Duration 00:03:42
#
# Epoch 85 || Loss:0.020062 || Training F1 0.897751 || Training Accuracy 0.814473 || Validation F1 0.870522 || Validation Accuracy 0.770729 || Max F1 0.874134 || LR 0.001000 || Duration 00:03:42
#
# Epoch 86 || Loss:0.023969 || Training F1 0.895917 || Training Accuracy 0.811458 || Validation F1 0.860633 || Validation Accuracy 0.755360 || Max F1 0.874134 || LR 0.001000 || Duration 00:03:42
#
# Epoch 87 || Loss:0.024093 || Training F1 0.907120 || Training Accuracy 0.830027 || Validation F1 0.861847 || Validation Accuracy 0.757233 || Max F1 0.874134 || LR 0.001000 || Duration 00:03:42
#
# Epoch 88 || Loss:0.019425 || Training F1 0.907640 || Training Accuracy 0.830898 || Validation F1 0.866994 || Validation Accuracy 0.765216 || Max F1 0.874134 || LR 0.001000 || Duration 00:03:42
#
# Epoch 89 || Loss:0.028231 || Training F1 0.905826 || Training Accuracy 0.827863 || Validation F1 0.865658 || Validation Accuracy 0.763137 || Max F1 0.874134 || LR 0.001000 || Duration 00:03:42
#
# Epoch 90 || Loss:0.019209 || Training F1 0.900011 || Training Accuracy 0.818201 || Validation F1 0.856485 || Validation Accuracy 0.748993 || Max F1 0.874134 || LR 0.001000 || Duration 00:03:42
#
# Epoch 91 || Loss:0.019941 || Training F1 0.907349 || Training Accuracy 0.830411 || Validation F1 0.870975 || Validation Accuracy 0.771440 || Max F1 0.874134 || LR 0.001000 || Duration 00:03:42
#
# Epoch 92 || Loss:0.022238 || Training F1 0.874692 || Training Accuracy 0.777290 || Validation F1 0.850371 || Validation Accuracy 0.739692 || Max F1 0.874134 || LR 0.001000 || Duration 00:03:42
#
# Epoch 93 || Loss:0.021296 || Training F1 0.899536 || Training Accuracy 0.817414 || Validation F1 0.861376 || Validation Accuracy 0.756506 || Max F1 0.874134 || LR 0.001000 || Duration 00:03:42
#
# Epoch 94 || Loss:0.021057 || Training F1 0.906032 || Training Accuracy 0.828207 || Validation F1 0.869894 || Validation Accuracy 0.769746 || Max F1 0.874134 || LR 0.001000 || Duration 00:03:42
#
# Epoch 95 || Loss:0.027911 || Training F1 0.877476 || Training Accuracy 0.781699 || Validation F1 0.860487 || Validation Accuracy 0.755136 || Max F1 0.874134 || LR 0.001000 || Duration 00:03:42
#
# Epoch 96 || Loss:0.018943 || Training F1 0.891677 || Training Accuracy 0.804529 || Validation F1 0.863339 || Validation Accuracy 0.759540 || Max F1 0.874134 || LR 0.001000 || Duration 00:03:41
#
# Epoch 97 || Loss:0.021423 || Training F1 0.806543 || Training Accuracy 0.675804 || Validation F1 0.824539 || Validation Accuracy 0.701459 || Max F1 0.874134 || LR 0.001000 || Duration 00:03:41
#
# Epoch 98 || Loss:0.028845 || Training F1 0.902823 || Training Accuracy 0.822861 || Validation F1 0.862827 || Validation Accuracy 0.758747 || Max F1 0.874134 || LR 0.001000 || Duration 00:03:41
#
# Epoch 99 || Loss:0.018141 || Training F1 0.904789 || Training Accuracy 0.826132 || Validation F1 0.860219 || Validation Accuracy 0.754723 || Max F1 0.874134 || LR 0.001000 || Duration 00:03:41

# %% [markdown]
# ## TEST RESULTS

# %%
# Utilities
to_tensor = T.ToTensor() 
toPIL = T.ToPILImage()

DIM_IMG_TEST = 608

# %%
def load_test_dataset():
    root_test_dir = "/content/drive/MyDrive/ml_epfl/ml_road_segmentation/data/test_set_images/"
    test_i = 'test_'
    n = len(os.listdir(root_test_dir))
    test_imgs = [to_tensor(Image.open(root_test_dir + test_i + str(idx_img) +'/'+ test_i + str(idx_img) + '.png')).reshape((1, 3, DIM_IMG_TEST, DIM_IMG_TEST)) for idx_img in range(1, n+1)]
    return test_imgs
  
test_images = load_test_dataset()

# %%
def make_predictions(model, test_images):
    model.eval()
    predicted_images = [torch.argmax(model(img.to(device)), dim = 1).cpu().float() for img in test_images]
    return predicted_images

predictions = make_predictions(model, test_images)

# %%
plt.figure(figsize=(15,15))
IMG_INDEX = 40
images = [toPIL(test_images[IMG_INDEX].reshape((3, DIM_IMG_TEST, DIM_IMG_TEST))), toPIL(predictions[IMG_INDEX])]
for i, image in enumerate(images):
    plt.subplot(1, 2, i+1)
    plt.imshow(image)

# %% [markdown]
# ## JUST TO TRY ROTATION

# %%
# Just for testing
root_dir = "/content/drive/MyDrive/ml_epfl/ml_road_segmentation/data/training/images/"
files = os.listdir(root_dir)
to_tensor = T.ToTensor()
imgs = [to_tensor(Image.open(root_dir + files[i])) for i in range(1)]

ANGLE_ROTATION = 15
NB_ROT = 3
rot_imgs = imgs + [torch.from_numpy(sc.rotate(imgs[i], ANGLE_ROTATION*(idx_rot+1), axes =(1,2), reshape=False, mode="mirror")) for idx_rot in range(NB_ROT) for i in range(len(imgs)) ]

plt.figure(figsize=(25,25))
for i, image in enumerate(rot_imgs):
    plt.subplot(1, 4, i+1)
    plt.imshow(toPIL(image))

# %%
def change_color_imgs(imgs):
    return [T.Grayscale()(imgs[i]) for i in  range(n)]

def blur_imgs(imgs):
    return [T.functional.gaussian_blur(imgs[i], kernel_size=(5, 9)) for i in range(len(imgs))]

def jitter_imgs(imgs):
    jitter = T.ColorJitter(brightness=[2,2], contrast=0, saturation=0, hue=0)
    return [jitter(imgs[i]) for i in  range(len(imgs))]
